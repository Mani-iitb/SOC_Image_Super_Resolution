# %%
from PIL import Image
import numpy as np
import os
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import torch 
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import vgg19
from torchvision.transforms import RandomCrop, ToTensor, Resize,Normalize, Compose
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from skimage.metrics import structural_similarity as ssim
from torchvision import transforms

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
class ImageDataset(Dataset):
    def __init__(self, hr_dir, crop_size=96, upscale_factor=4):
        self.hr_dir = hr_dir
        self.hr_files = os.listdir(hr_dir)
        self.hr_transform = RandomCrop(crop_size)
        self.upscale_factor = upscale_factor
        self.lr_size = crop_size // upscale_factor
        self.lr_transform = Resize((self.lr_size, self.lr_size), interpolation=Image.BICUBIC)
    
    def __len__(self):
        return len(self.hr_files)
    
    def __getitem__(self, idx):
        hr_name = os.path.join(self.hr_dir, self.hr_files[idx])
        # hr_img = Image.open(hr_name).convert('RGB')
        hr_img = Image.open(hr_name).convert('YCbCr')
        hr_y, cb, cr = hr_img.split()
        hr_y = self.hr_transform(hr_y)
        lr_y = self.lr_transform(hr_y)
        
        return {
            'hr_img': ToTensor()(hr_y),
            'lr_img': ToTensor()(lr_y)
        }

# %%
class ResidualDenseBlock(nn.Module):
    def __init__(self, in_channels, out_channels, beta=0.2):
        super(ResidualDenseBlock, self).__init__()
        self.beta = beta
        self.conv1 = nn.Conv2d(in_channels + out_channels * 0, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.conv2 = nn.Conv2d(in_channels + out_channels * 1, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.conv3 = nn.Conv2d(in_channels + out_channels * 2, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.conv4 = nn.Conv2d(in_channels + out_channels * 3, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.conv5 = nn.Conv2d(in_channels + out_channels * 4, in_channels, kernel_size=3, stride=1, padding=1, bias=False)
        
        self.lRelu = nn.LeakyReLU(0.2, inplace=True)
        
    def forward(self, x):
        residual = x
        
        out1 = self.lRelu(self.conv1(x))
        out2 = self.lRelu(self.conv2(torch.cat([x, out1], 1)))
        out3 = self.lRelu(self.conv3(torch.cat([x, out1, out2], 1)))
        out4 = self.lRelu(self.conv4(torch.cat([x, out1, out2, out3], 1)))
        out5 = self.conv5(torch.cat([x, out1, out2, out3, out4], 1))
        
        out5 = torch.mul(out5, self.beta)
        return out5 + residual
        
class ResidualResidualDenseBlock(nn.Module):
    def __init__(self, in_channels, out_channels, beta = 0.2):
        super(ResidualResidualDenseBlock, self).__init__()
        self.beta = beta
        self.rdb1 = ResidualDenseBlock(in_channels, out_channels, beta)
        self.rdb2 = ResidualDenseBlock(in_channels, out_channels, beta)
        self.rdb3 = ResidualDenseBlock(in_channels, out_channels, beta)
    
    def forward(self, x):
        residual = x
        x = self.rdb1(x)
        x = self.rdb2(x)
        x = self.rdb3(x)
        x = torch.mul(x, self.beta)
        return x + residual
    
class UpSample(nn.Module):
    def __init__(self, in_channels, kernel_size=3, padding=1, stride=1, upScale_factor=2):
        super(UpSample, self).__init__()
        self.upsample = nn.Sequential(
            nn.Conv2d(in_channels, in_channels * (upScale_factor ** 2), kernel_size=kernel_size, stride=stride, padding=padding),
            nn.PixelShuffle(upScale_factor),
            nn.PReLU()
        )
    
    def forward(self, x):
        return self.upsample(x)
    
class Generator(nn.Module):
    def __init__(self, num_Res_blocks = 16, upScale_factor = 4, num_res_block_channels = 64):
        super(Generator, self).__init__()
        
        self.intial_block = nn.Sequential(
            nn.Conv2d(1, num_res_block_channels, kernel_size=9, stride=1, padding=4),
            nn.PReLU()
        )
        self.res_block = nn.Sequential(*[ResidualResidualDenseBlock(in_channels=num_res_block_channels, out_channels=32) for _ in range(num_Res_blocks)])
        self.post_res = nn.Conv2d(num_res_block_channels, num_res_block_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.upsample_block = nn.Sequential(*[UpSample(num_res_block_channels) for _ in range(upScale_factor // 2)])
        self.final = nn.Conv2d(num_res_block_channels, 1, kernel_size=9, stride=1, padding=4)
        
    def forward(self, x):
        initial = self.intial_block(x)
        res = self.res_block(initial)
        post_residual = self.post_res(res)
        x = initial + post_residual
        x = self.upsample_block(x)
        x = self.final(x)
        return torch.sigmoid(x)

# %%
class DiscriminatorBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, use_bn=True):
        super(DiscriminatorBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1)
        self.bn = nn.BatchNorm2d(out_channels) if use_bn else None
        self.lrelu = nn.LeakyReLU(0.2, inplace=True)
        
    def forward(self, x):
        x = self.conv(x)
        if self.bn:
            x = self.bn(x)
        x = self.lrelu(x)
        return x

class Discriminator(nn.Module):
    def __init__(self, input_shape=(3,96,96)):
        super(Discriminator, self).__init__()
        self.features = nn.Sequential(
            DiscriminatorBlock(1, 64, use_bn=False),
            DiscriminatorBlock(64, 64, stride=2),
            DiscriminatorBlock(64, 128),
            DiscriminatorBlock(128, 128, stride=2),
            DiscriminatorBlock(128, 256),
            DiscriminatorBlock(256, 256, stride=2),
            DiscriminatorBlock(256, 512),
            DiscriminatorBlock(512, 512, stride=2),
        )
        
        self.output_shape = self.get_output_shape(input_shape)
        self.dense_block = nn.Sequential(
            nn.Linear(self.output_shape, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 1)
        )
    
    def get_output_shape(self, input_shape):
        with torch.no_grad():
            dummy = torch.zeros(1, *input_shape)
            output = self.features(dummy)
            return int(torch.prod(torch.tensor(output.shape[1:])))
    
    def forward(self, x):
        features = self.features(x)
        flat = features.view(features.size(0), -1)
        return self.dense_block(flat)

# %%
def D_ra(real_logits, fake_logits):
    real_mean = torch.mean(fake_logits)
    fake_mean = torch.mean(real_logits)

    D_real = torch.sigmoid(real_logits - fake_mean)
    D_fake = torch.sigmoid(fake_logits - real_mean)

    return D_real, D_fake

def discriminator_loss(D, real_imgs, fake_imgs):
    real_logits = D(real_imgs)
    fake_logits = D(fake_imgs)
    
    D_real, D_fake = D_ra(real_logits, fake_logits)

    loss_real = torch.log(D_real + 1e-12).mean()
    loss_fake = torch.log(1 - D_fake + 1e-12).mean()
    return - (loss_real + loss_fake)

def generator_loss(D, real_imgs, fake_imgs):
    real_logits = D(real_imgs)
    fake_logits = D(fake_imgs)
    
    D_real, D_fake = D_ra(real_logits, fake_logits)

    loss_real = torch.log(1 - D_real + 1e-12).mean()
    loss_fake = torch.log(D_fake + 1e-12).mean()
    return - (loss_real + loss_fake)

class PercepLoss(nn.Module):
    def __init__(self):
        super(PercepLoss, self).__init__()
        vgg = vgg19(pretrained=True).features
        self.vgg_layers = nn.Sequential(*list(vgg)[:8]).eval()
        for param in self.vgg_layers.parameters():
            param.requires_grad = False
        
        self.register_buffer('mean', torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1))
        self.register_buffer('std', torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1))
    
    def forward(self, sr, hr):
        sr_norm = (sr - self.mean) / self.std
        hr_norm = (hr - self.mean) / self.std
        sr_vgg = self.vgg_layers(sr_norm)
        hr_vgg = self.vgg_layers(hr_norm)
        return F.mse_loss(sr_vgg, hr_vgg)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

dataset = ImageDataset(hr_dir="DIV2K_train_HR", crop_size=192)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True, num_workers=4, pin_memory=True)

generator = Generator().to(device)
discriminator = Discriminator(input_shape=(1,192,192)).to(device)

optimizer_G = optim.Adam(generator.parameters(), lr=2e-4,  betas=(0.9, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=2e-4,  betas=(0.9, 0.999))
scheduler_G = StepLR(optimizer_G, step_size=25, gamma=0.5)
scheduler_D = StepLR(optimizer_G, step_size=25, gamma=0.5)

criterion_percep_loss = PercepLoss().to(device)

bce_loss_G = nn.BCELoss()
bce_loss_D = nn.BCELoss()
pixel_loss = nn.L1Loss() 

weight_generator_loss = 5e-3
weight_l1_loss = 1e-2

num_epochs = 100
# Out:
# cuda
# /users/pg24/manivannan/miniconda3/envs/newEnv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /users/pg24/manivannan/miniconda3/envs/newEnv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
generator.to(device)
discriminator.to(device)

mean = torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1).to(device)
std = torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1).to(device)

for epoch in range(100):  # Pre-train
    for i, batch in enumerate(dataloader):
        lr_imgs = batch['lr_img'].to(device)
        hr_imgs = batch['hr_img'].to(device)
        
        optimizer_G.zero_grad()
        sr_imgs = generator(lr_imgs)
        loss = pixel_loss(sr_imgs, hr_imgs)
        loss.backward()
        optimizer_G.step()
        
        if i % 10 == 0:
            print(f"Pre-train Epoch {epoch}, Batch {i}, Pixel Loss: {loss.item():.6f}")


for epoch in range(num_epochs):
    for i, imgs in enumerate(dataloader):
        
        lr_patch = imgs["lr_img"].to(device)
        hr_patch = imgs["hr_img"].to(device)
        
        # Train Discriminator
        optimizer_D.zero_grad()
        with torch.no_grad():
            sr_patch = generator(lr_patch.detach())
        d_loss = discriminator_loss(discriminator, hr_patch, sr_patch)
        d_loss.backward()
        optimizer_D.step()
        
        
        # Train Generator
        optimizer_G.zero_grad()
        
        sr_patch = generator(lr_patch)

        sr_norm = (sr_patch - mean) / std
        hr_norm = (hr_patch - mean) / std
        
        percep_loss = criterion_percep_loss(sr_patch, hr_patch)
        adverserial_loss = generator_loss(discriminator, hr_patch, sr_patch)
        l1_loss = pixel_loss(sr_patch, hr_patch)
        
        g_loss = percep_loss + (weight_generator_loss * adverserial_loss) + (weight_l1_loss * l1_loss)
        g_loss.backward()
        optimizer_G.step()

        if i % 10 == 0:
            print(f"Epoch {epoch}/{num_epochs}, Step {i}, G Loss: {g_loss.item()}, D Loss: {d_loss.item()}")
    
    scheduler_G.step()
    scheduler_D.step()
# Out:
# Pre-train Epoch 0, Batch 0, Pixel Loss: 0.214277
# Pre-train Epoch 0, Batch 10, Pixel Loss: 0.167145
# Pre-train Epoch 0, Batch 20, Pixel Loss: 0.080394
# Pre-train Epoch 0, Batch 30, Pixel Loss: 0.084531
# Pre-train Epoch 0, Batch 40, Pixel Loss: 0.074878
# Pre-train Epoch 1, Batch 0, Pixel Loss: 0.066352
# Pre-train Epoch 1, Batch 10, Pixel Loss: 0.063799
# Pre-train Epoch 1, Batch 20, Pixel Loss: 0.062142
# Pre-train Epoch 1, Batch 30, Pixel Loss: 0.060858
# Pre-train Epoch 1, Batch 40, Pixel Loss: 0.041941
# Pre-train Epoch 2, Batch 0, Pixel Loss: 0.083239
# Pre-train Epoch 2, Batch 10, Pixel Loss: 0.060314
# Pre-train Epoch 2, Batch 20, Pixel Loss: 0.061184
# Pre-train Epoch 2, Batch 30, Pixel Loss: 0.044619
# Pre-train Epoch 2, Batch 40, Pixel Loss: 0.056731
# Pre-train Epoch 3, Batch 0, Pixel Loss: 0.053066
# Pre-train Epoch 3, Batch 10, Pixel Loss: 0.050054
# Pre-train Epoch 3, Batch 20, Pixel Loss: 0.032267
# Pre-train Epoch 3, Batch 30, Pixel Loss: 0.030065
# Pre-train Epoch 3, Batch 40, Pixel Loss: 0.044640
# Pre-train Epoch 4, Batch 0, Pixel Loss: 0.035296
# Pre-train Epoch 4, Batch 10, Pixel Loss: 0.042725
# Pre-train Epoch 4, Batch 20, Pixel Loss: 0.032191
# Pre-train Epoch 4, Batch 30, Pixel Loss: 0.036666
# Pre-train Epoch 4, Batch 40, Pixel Loss: 0.039770
# Pre-train Epoch 5, Batch 0, Pixel Loss: 0.036886
# Pre-train Epoch 5, Batch 10, Pixel Loss: 0.028045
# Pre-train Epoch 5, Batch 20, Pixel Loss: 0.058580
# Pre-train Epoch 5, Batch 30, Pixel Loss: 0.037086
# Pre-train Epoch 5, Batch 40, Pixel Loss: 0.047196
# Pre-train Epoch 6, Batch 0, Pixel Loss: 0.050280
# Pre-train Epoch 6, Batch 10, Pixel Loss: 0.037543
# Pre-train Epoch 6, Batch 20, Pixel Loss: 0.035107
# Pre-train Epoch 6, Batch 30, Pixel Loss: 0.043257
# Pre-train Epoch 6, Batch 40, Pixel Loss: 0.037000
# Pre-train Epoch 7, Batch 0, Pixel Loss: 0.038966
# Pre-train Epoch 7, Batch 10, Pixel Loss: 0.034082
# Pre-train Epoch 7, Batch 20, Pixel Loss: 0.028551
# Pre-train Epoch 7, Batch 30, Pixel Loss: 0.038939
# Pre-train Epoch 7, Batch 40, Pixel Loss: 0.034672
# Pre-train Epoch 8, Batch 0, Pixel Loss: 0.032371
# Pre-train Epoch 8, Batch 10, Pixel Loss: 0.039181
# Pre-train Epoch 8, Batch 20, Pixel Loss: 0.040073
# Pre-train Epoch 8, Batch 30, Pixel Loss: 0.042187
# Pre-train Epoch 8, Batch 40, Pixel Loss: 0.038099
# Pre-train Epoch 9, Batch 0, Pixel Loss: 0.033629
# Pre-train Epoch 9, Batch 10, Pixel Loss: 0.038015
# Pre-train Epoch 9, Batch 20, Pixel Loss: 0.033477
# Pre-train Epoch 9, Batch 30, Pixel Loss: 0.031316
# Pre-train Epoch 9, Batch 40, Pixel Loss: 0.031479
# Pre-train Epoch 10, Batch 0, Pixel Loss: 0.024162
# Pre-train Epoch 10, Batch 10, Pixel Loss: 0.035754
# Pre-train Epoch 10, Batch 20, Pixel Loss: 0.042216
# Pre-train Epoch 10, Batch 30, Pixel Loss: 0.033888
# Pre-train Epoch 10, Batch 40, Pixel Loss: 0.042516
# Pre-train Epoch 11, Batch 0, Pixel Loss: 0.048271
# Pre-train Epoch 11, Batch 10, Pixel Loss: 0.036242
# Pre-train Epoch 11, Batch 20, Pixel Loss: 0.034125
# Pre-train Epoch 11, Batch 30, Pixel Loss: 0.034448
# Pre-train Epoch 11, Batch 40, Pixel Loss: 0.029725
# Pre-train Epoch 12, Batch 0, Pixel Loss: 0.024543
# Pre-train Epoch 12, Batch 10, Pixel Loss: 0.034000
# Pre-train Epoch 12, Batch 20, Pixel Loss: 0.042286
# Pre-train Epoch 12, Batch 30, Pixel Loss: 0.029834
# Pre-train Epoch 12, Batch 40, Pixel Loss: 0.041768
# Pre-train Epoch 13, Batch 0, Pixel Loss: 0.025422
# Pre-train Epoch 13, Batch 10, Pixel Loss: 0.040779
# Pre-train Epoch 13, Batch 20, Pixel Loss: 0.045362
# Pre-train Epoch 13, Batch 30, Pixel Loss: 0.032600
# Pre-train Epoch 13, Batch 40, Pixel Loss: 0.037357
# Pre-train Epoch 14, Batch 0, Pixel Loss: 0.036194
# Pre-train Epoch 14, Batch 10, Pixel Loss: 0.032600
# Pre-train Epoch 14, Batch 20, Pixel Loss: 0.041549
# Pre-train Epoch 14, Batch 30, Pixel Loss: 0.022008
# Pre-train Epoch 14, Batch 40, Pixel Loss: 0.043698
# Pre-train Epoch 15, Batch 0, Pixel Loss: 0.031581
# Pre-train Epoch 15, Batch 10, Pixel Loss: 0.024260
# Pre-train Epoch 15, Batch 20, Pixel Loss: 0.033940
# Pre-train Epoch 15, Batch 30, Pixel Loss: 0.045032
# Pre-train Epoch 15, Batch 40, Pixel Loss: 0.035627
# Pre-train Epoch 16, Batch 0, Pixel Loss: 0.018776
# Pre-train Epoch 16, Batch 10, Pixel Loss: 0.032064
# Pre-train Epoch 16, Batch 20, Pixel Loss: 0.029438
# Pre-train Epoch 16, Batch 30, Pixel Loss: 0.043699
# Pre-train Epoch 16, Batch 40, Pixel Loss: 0.031465
# Pre-train Epoch 17, Batch 0, Pixel Loss: 0.034670
# Pre-train Epoch 17, Batch 10, Pixel Loss: 0.031960
# Pre-train Epoch 17, Batch 20, Pixel Loss: 0.030719
# Pre-train Epoch 17, Batch 30, Pixel Loss: 0.040740
# Pre-train Epoch 17, Batch 40, Pixel Loss: 0.035781
# Pre-train Epoch 18, Batch 0, Pixel Loss: 0.032835
# Pre-train Epoch 18, Batch 10, Pixel Loss: 0.029991
# Pre-train Epoch 18, Batch 20, Pixel Loss: 0.040137
# Pre-train Epoch 18, Batch 30, Pixel Loss: 0.060446
# Pre-train Epoch 18, Batch 40, Pixel Loss: 0.042087
# Pre-train Epoch 19, Batch 0, Pixel Loss: 0.026618
# Pre-train Epoch 19, Batch 10, Pixel Loss: 0.023111
# Pre-train Epoch 19, Batch 20, Pixel Loss: 0.036698
# Pre-train Epoch 19, Batch 30, Pixel Loss: 0.038798
# Pre-train Epoch 19, Batch 40, Pixel Loss: 0.028325
# Pre-train Epoch 20, Batch 0, Pixel Loss: 0.027366
# Pre-train Epoch 20, Batch 10, Pixel Loss: 0.025204
# Pre-train Epoch 20, Batch 20, Pixel Loss: 0.027710
# Pre-train Epoch 20, Batch 30, Pixel Loss: 0.042925
# Pre-train Epoch 20, Batch 40, Pixel Loss: 0.049845
# Pre-train Epoch 21, Batch 0, Pixel Loss: 0.028355
# Pre-train Epoch 21, Batch 10, Pixel Loss: 0.019460
# Pre-train Epoch 21, Batch 20, Pixel Loss: 0.034423
# Pre-train Epoch 21, Batch 30, Pixel Loss: 0.033840
# Pre-train Epoch 21, Batch 40, Pixel Loss: 0.040226
# Pre-train Epoch 22, Batch 0, Pixel Loss: 0.047684
# Pre-train Epoch 22, Batch 10, Pixel Loss: 0.035314
# Pre-train Epoch 22, Batch 20, Pixel Loss: 0.027523
# Pre-train Epoch 22, Batch 30, Pixel Loss: 0.027404
# Pre-train Epoch 22, Batch 40, Pixel Loss: 0.022450
# Pre-train Epoch 23, Batch 0, Pixel Loss: 0.026505
# Pre-train Epoch 23, Batch 10, Pixel Loss: 0.035523
# Pre-train Epoch 23, Batch 20, Pixel Loss: 0.029981
# Pre-train Epoch 23, Batch 30, Pixel Loss: 0.029481
# Pre-train Epoch 23, Batch 40, Pixel Loss: 0.035193
# Pre-train Epoch 24, Batch 0, Pixel Loss: 0.024602
# Pre-train Epoch 24, Batch 10, Pixel Loss: 0.031334
# Pre-train Epoch 24, Batch 20, Pixel Loss: 0.042964
# Pre-train Epoch 24, Batch 30, Pixel Loss: 0.032512
# Pre-train Epoch 24, Batch 40, Pixel Loss: 0.033613
# Pre-train Epoch 25, Batch 0, Pixel Loss: 0.028755
# Pre-train Epoch 25, Batch 10, Pixel Loss: 0.037328
# Pre-train Epoch 25, Batch 20, Pixel Loss: 0.034441
# Pre-train Epoch 25, Batch 30, Pixel Loss: 0.029145
# Pre-train Epoch 25, Batch 40, Pixel Loss: 0.030518
# Pre-train Epoch 26, Batch 0, Pixel Loss: 0.030319
# Pre-train Epoch 26, Batch 10, Pixel Loss: 0.025680
# Pre-train Epoch 26, Batch 20, Pixel Loss: 0.031665
# Pre-train Epoch 26, Batch 30, Pixel Loss: 0.027176
# Pre-train Epoch 26, Batch 40, Pixel Loss: 0.036694
# Pre-train Epoch 27, Batch 0, Pixel Loss: 0.033338
# Pre-train Epoch 27, Batch 10, Pixel Loss: 0.022927
# Pre-train Epoch 27, Batch 20, Pixel Loss: 0.025686
# Pre-train Epoch 27, Batch 30, Pixel Loss: 0.047490
# Pre-train Epoch 27, Batch 40, Pixel Loss: 0.047928
# Pre-train Epoch 28, Batch 0, Pixel Loss: 0.029625
# Pre-train Epoch 28, Batch 10, Pixel Loss: 0.041407
# Pre-train Epoch 28, Batch 20, Pixel Loss: 0.029712
# Pre-train Epoch 28, Batch 30, Pixel Loss: 0.029342
# Pre-train Epoch 28, Batch 40, Pixel Loss: 0.021032
# Pre-train Epoch 29, Batch 0, Pixel Loss: 0.024706
# Pre-train Epoch 29, Batch 10, Pixel Loss: 0.040168
# Pre-train Epoch 29, Batch 20, Pixel Loss: 0.032098
# Pre-train Epoch 29, Batch 30, Pixel Loss: 0.028874
# Pre-train Epoch 29, Batch 40, Pixel Loss: 0.029478
# Pre-train Epoch 30, Batch 0, Pixel Loss: 0.043499
# Pre-train Epoch 30, Batch 10, Pixel Loss: 0.038281
# Pre-train Epoch 30, Batch 20, Pixel Loss: 0.031507
# Pre-train Epoch 30, Batch 30, Pixel Loss: 0.023033
# Pre-train Epoch 30, Batch 40, Pixel Loss: 0.034811
# Pre-train Epoch 31, Batch 0, Pixel Loss: 0.040811
# Pre-train Epoch 31, Batch 10, Pixel Loss: 0.032959
# Pre-train Epoch 31, Batch 20, Pixel Loss: 0.035818
# Pre-train Epoch 31, Batch 30, Pixel Loss: 0.027752
# Pre-train Epoch 31, Batch 40, Pixel Loss: 0.032273
# Pre-train Epoch 32, Batch 0, Pixel Loss: 0.024835
# Pre-train Epoch 32, Batch 10, Pixel Loss: 0.040265
# Pre-train Epoch 32, Batch 20, Pixel Loss: 0.021597
# Pre-train Epoch 32, Batch 30, Pixel Loss: 0.036828
# Pre-train Epoch 32, Batch 40, Pixel Loss: 0.027639
# Pre-train Epoch 33, Batch 0, Pixel Loss: 0.029599
# Pre-train Epoch 33, Batch 10, Pixel Loss: 0.023792
# Pre-train Epoch 33, Batch 20, Pixel Loss: 0.038932
# Pre-train Epoch 33, Batch 30, Pixel Loss: 0.043150
# Pre-train Epoch 33, Batch 40, Pixel Loss: 0.037255
# Pre-train Epoch 34, Batch 0, Pixel Loss: 0.026577
# Pre-train Epoch 34, Batch 10, Pixel Loss: 0.037131
# Pre-train Epoch 34, Batch 20, Pixel Loss: 0.036038
# Pre-train Epoch 34, Batch 30, Pixel Loss: 0.026378
# Pre-train Epoch 34, Batch 40, Pixel Loss: 0.028728
# Pre-train Epoch 35, Batch 0, Pixel Loss: 0.035753
# Pre-train Epoch 35, Batch 10, Pixel Loss: 0.037921
# Pre-train Epoch 35, Batch 20, Pixel Loss: 0.039419
# Pre-train Epoch 35, Batch 30, Pixel Loss: 0.023930
# Pre-train Epoch 35, Batch 40, Pixel Loss: 0.023288
# Pre-train Epoch 36, Batch 0, Pixel Loss: 0.030614
# Pre-train Epoch 36, Batch 10, Pixel Loss: 0.027115
# Pre-train Epoch 36, Batch 20, Pixel Loss: 0.018702
# Pre-train Epoch 36, Batch 30, Pixel Loss: 0.035994
# Pre-train Epoch 36, Batch 40, Pixel Loss: 0.030632
# Pre-train Epoch 37, Batch 0, Pixel Loss: 0.019863
# Pre-train Epoch 37, Batch 10, Pixel Loss: 0.024343
# Pre-train Epoch 37, Batch 20, Pixel Loss: 0.030525
# Pre-train Epoch 37, Batch 30, Pixel Loss: 0.036247
# Pre-train Epoch 37, Batch 40, Pixel Loss: 0.029159
# Pre-train Epoch 38, Batch 0, Pixel Loss: 0.031864
# Pre-train Epoch 38, Batch 10, Pixel Loss: 0.031578
# Pre-train Epoch 38, Batch 20, Pixel Loss: 0.035078
# Pre-train Epoch 38, Batch 30, Pixel Loss: 0.039898
# Pre-train Epoch 38, Batch 40, Pixel Loss: 0.024171
# Pre-train Epoch 39, Batch 0, Pixel Loss: 0.044990
# Pre-train Epoch 39, Batch 10, Pixel Loss: 0.029568
# Pre-train Epoch 39, Batch 20, Pixel Loss: 0.029639
# Pre-train Epoch 39, Batch 30, Pixel Loss: 0.028733
# Pre-train Epoch 39, Batch 40, Pixel Loss: 0.021719
# Pre-train Epoch 40, Batch 0, Pixel Loss: 0.038907
# Pre-train Epoch 40, Batch 10, Pixel Loss: 0.025258
# Pre-train Epoch 40, Batch 20, Pixel Loss: 0.031699
# Pre-train Epoch 40, Batch 30, Pixel Loss: 0.024694
# Pre-train Epoch 40, Batch 40, Pixel Loss: 0.038175
# Pre-train Epoch 41, Batch 0, Pixel Loss: 0.031555
# Pre-train Epoch 41, Batch 10, Pixel Loss: 0.032119
# Pre-train Epoch 41, Batch 20, Pixel Loss: 0.037879
# Pre-train Epoch 41, Batch 30, Pixel Loss: 0.027690
# Pre-train Epoch 41, Batch 40, Pixel Loss: 0.032845
# Pre-train Epoch 42, Batch 0, Pixel Loss: 0.036584
# Pre-train Epoch 42, Batch 10, Pixel Loss: 0.032585
# Pre-train Epoch 42, Batch 20, Pixel Loss: 0.034963
# Pre-train Epoch 42, Batch 30, Pixel Loss: 0.033330
# Pre-train Epoch 42, Batch 40, Pixel Loss: 0.033447
# Pre-train Epoch 43, Batch 0, Pixel Loss: 0.025087
# Pre-train Epoch 43, Batch 10, Pixel Loss: 0.041165
# Pre-train Epoch 43, Batch 20, Pixel Loss: 0.035565
# Pre-train Epoch 43, Batch 30, Pixel Loss: 0.036607
# Pre-train Epoch 43, Batch 40, Pixel Loss: 0.033709
# Pre-train Epoch 44, Batch 0, Pixel Loss: 0.026577
# Pre-train Epoch 44, Batch 10, Pixel Loss: 0.029709
# Pre-train Epoch 44, Batch 20, Pixel Loss: 0.028725
# Pre-train Epoch 44, Batch 30, Pixel Loss: 0.023625
# Pre-train Epoch 44, Batch 40, Pixel Loss: 0.032776
# Pre-train Epoch 45, Batch 0, Pixel Loss: 0.045597
# Pre-train Epoch 45, Batch 10, Pixel Loss: 0.040462
# Pre-train Epoch 45, Batch 20, Pixel Loss: 0.039507
# Pre-train Epoch 45, Batch 30, Pixel Loss: 0.034138
# Pre-train Epoch 45, Batch 40, Pixel Loss: 0.024849
# Pre-train Epoch 46, Batch 0, Pixel Loss: 0.022493
# Pre-train Epoch 46, Batch 10, Pixel Loss: 0.029179
# Pre-train Epoch 46, Batch 20, Pixel Loss: 0.038255
# Pre-train Epoch 46, Batch 30, Pixel Loss: 0.040829
# Pre-train Epoch 46, Batch 40, Pixel Loss: 0.024142
# Pre-train Epoch 47, Batch 0, Pixel Loss: 0.030504
# Pre-train Epoch 47, Batch 10, Pixel Loss: 0.026920
# Pre-train Epoch 47, Batch 20, Pixel Loss: 0.027903
# Pre-train Epoch 47, Batch 30, Pixel Loss: 0.038364
# Pre-train Epoch 47, Batch 40, Pixel Loss: 0.029237
# Pre-train Epoch 48, Batch 0, Pixel Loss: 0.021600
# Pre-train Epoch 48, Batch 10, Pixel Loss: 0.030035
# Pre-train Epoch 48, Batch 20, Pixel Loss: 0.028437
# Pre-train Epoch 48, Batch 30, Pixel Loss: 0.037375
# Pre-train Epoch 48, Batch 40, Pixel Loss: 0.031096
# Pre-train Epoch 49, Batch 0, Pixel Loss: 0.035582
# Pre-train Epoch 49, Batch 10, Pixel Loss: 0.037038
# Pre-train Epoch 49, Batch 20, Pixel Loss: 0.019348
# Pre-train Epoch 49, Batch 30, Pixel Loss: 0.030616
# Pre-train Epoch 49, Batch 40, Pixel Loss: 0.020959
# Pre-train Epoch 50, Batch 0, Pixel Loss: 0.029327
# Pre-train Epoch 50, Batch 10, Pixel Loss: 0.034321
# Pre-train Epoch 50, Batch 20, Pixel Loss: 0.033115
# Pre-train Epoch 50, Batch 30, Pixel Loss: 0.033316
# Pre-train Epoch 50, Batch 40, Pixel Loss: 0.033261
# Pre-train Epoch 51, Batch 0, Pixel Loss: 0.026879
# Pre-train Epoch 51, Batch 10, Pixel Loss: 0.034977
# Pre-train Epoch 51, Batch 20, Pixel Loss: 0.023498
# Pre-train Epoch 51, Batch 30, Pixel Loss: 0.030412
# Pre-train Epoch 51, Batch 40, Pixel Loss: 0.031208
# Pre-train Epoch 52, Batch 0, Pixel Loss: 0.024977
# Pre-train Epoch 52, Batch 10, Pixel Loss: 0.040049
# Pre-train Epoch 52, Batch 20, Pixel Loss: 0.033368
# Pre-train Epoch 52, Batch 30, Pixel Loss: 0.021128
# Pre-train Epoch 52, Batch 40, Pixel Loss: 0.043048
# Pre-train Epoch 53, Batch 0, Pixel Loss: 0.032240
# Pre-train Epoch 53, Batch 10, Pixel Loss: 0.037813
# Pre-train Epoch 53, Batch 20, Pixel Loss: 0.022440
# Pre-train Epoch 53, Batch 30, Pixel Loss: 0.037660
# Pre-train Epoch 53, Batch 40, Pixel Loss: 0.020341
# Pre-train Epoch 54, Batch 0, Pixel Loss: 0.030338
# Pre-train Epoch 54, Batch 10, Pixel Loss: 0.032832
# Pre-train Epoch 54, Batch 20, Pixel Loss: 0.032814
# Pre-train Epoch 54, Batch 30, Pixel Loss: 0.025397
# Pre-train Epoch 54, Batch 40, Pixel Loss: 0.034692
# Pre-train Epoch 55, Batch 0, Pixel Loss: 0.027113
# Pre-train Epoch 55, Batch 10, Pixel Loss: 0.041342
# Pre-train Epoch 55, Batch 20, Pixel Loss: 0.025443
# Pre-train Epoch 55, Batch 30, Pixel Loss: 0.034464
# Pre-train Epoch 55, Batch 40, Pixel Loss: 0.040342
# Pre-train Epoch 56, Batch 0, Pixel Loss: 0.031542
# Pre-train Epoch 56, Batch 10, Pixel Loss: 0.037573
# Pre-train Epoch 56, Batch 20, Pixel Loss: 0.025389
# Pre-train Epoch 56, Batch 30, Pixel Loss: 0.025141
# Pre-train Epoch 56, Batch 40, Pixel Loss: 0.033582
# Pre-train Epoch 57, Batch 0, Pixel Loss: 0.043445
# Pre-train Epoch 57, Batch 10, Pixel Loss: 0.041231
# Pre-train Epoch 57, Batch 20, Pixel Loss: 0.038410
# Pre-train Epoch 57, Batch 30, Pixel Loss: 0.032898
# Pre-train Epoch 57, Batch 40, Pixel Loss: 0.026695
# Pre-train Epoch 58, Batch 0, Pixel Loss: 0.029285
# Pre-train Epoch 58, Batch 10, Pixel Loss: 0.029454
# Pre-train Epoch 58, Batch 20, Pixel Loss: 0.028431
# Pre-train Epoch 58, Batch 30, Pixel Loss: 0.034380
# Pre-train Epoch 58, Batch 40, Pixel Loss: 0.019580
# Pre-train Epoch 59, Batch 0, Pixel Loss: 0.031048
# Pre-train Epoch 59, Batch 10, Pixel Loss: 0.033720
# Pre-train Epoch 59, Batch 20, Pixel Loss: 0.022973
# Pre-train Epoch 59, Batch 30, Pixel Loss: 0.020772
# Pre-train Epoch 59, Batch 40, Pixel Loss: 0.032658
# Pre-train Epoch 60, Batch 0, Pixel Loss: 0.028845
# Pre-train Epoch 60, Batch 10, Pixel Loss: 0.028873
# Pre-train Epoch 60, Batch 20, Pixel Loss: 0.026395
# Pre-train Epoch 60, Batch 30, Pixel Loss: 0.040488
# Pre-train Epoch 60, Batch 40, Pixel Loss: 0.022742
# Pre-train Epoch 61, Batch 0, Pixel Loss: 0.034097
# Pre-train Epoch 61, Batch 10, Pixel Loss: 0.040213
# Pre-train Epoch 61, Batch 20, Pixel Loss: 0.018310
# Pre-train Epoch 61, Batch 30, Pixel Loss: 0.033390
# Pre-train Epoch 61, Batch 40, Pixel Loss: 0.038903
# Pre-train Epoch 62, Batch 0, Pixel Loss: 0.038721
# Pre-train Epoch 62, Batch 10, Pixel Loss: 0.023651
# Pre-train Epoch 62, Batch 20, Pixel Loss: 0.024535
# Pre-train Epoch 62, Batch 30, Pixel Loss: 0.029049
# Pre-train Epoch 62, Batch 40, Pixel Loss: 0.045142
# Pre-train Epoch 63, Batch 0, Pixel Loss: 0.034907
# Pre-train Epoch 63, Batch 10, Pixel Loss: 0.032694
# Pre-train Epoch 63, Batch 20, Pixel Loss: 0.022634
# Pre-train Epoch 63, Batch 30, Pixel Loss: 0.024409
# Pre-train Epoch 63, Batch 40, Pixel Loss: 0.041808
# Pre-train Epoch 64, Batch 0, Pixel Loss: 0.023624
# Pre-train Epoch 64, Batch 10, Pixel Loss: 0.022061
# Pre-train Epoch 64, Batch 20, Pixel Loss: 0.023371
# Pre-train Epoch 64, Batch 30, Pixel Loss: 0.029074
# Pre-train Epoch 64, Batch 40, Pixel Loss: 0.021252
# Pre-train Epoch 65, Batch 0, Pixel Loss: 0.023983
# Pre-train Epoch 65, Batch 10, Pixel Loss: 0.026579
# Pre-train Epoch 65, Batch 20, Pixel Loss: 0.024482
# Pre-train Epoch 65, Batch 30, Pixel Loss: 0.024836
# Pre-train Epoch 65, Batch 40, Pixel Loss: 0.018433
# Pre-train Epoch 66, Batch 0, Pixel Loss: 0.030601
# Pre-train Epoch 66, Batch 10, Pixel Loss: 0.037235
# Pre-train Epoch 66, Batch 20, Pixel Loss: 0.035242
# Pre-train Epoch 66, Batch 30, Pixel Loss: 0.043639
# Pre-train Epoch 66, Batch 40, Pixel Loss: 0.022353
# Pre-train Epoch 67, Batch 0, Pixel Loss: 0.020819
# Pre-train Epoch 67, Batch 10, Pixel Loss: 0.028996
# Pre-train Epoch 67, Batch 20, Pixel Loss: 0.027149
# Pre-train Epoch 67, Batch 30, Pixel Loss: 0.024103
# Pre-train Epoch 67, Batch 40, Pixel Loss: 0.025562
# Pre-train Epoch 68, Batch 0, Pixel Loss: 0.033851
# Pre-train Epoch 68, Batch 10, Pixel Loss: 0.034594
# Pre-train Epoch 68, Batch 20, Pixel Loss: 0.024188
# Pre-train Epoch 68, Batch 30, Pixel Loss: 0.035856
# Pre-train Epoch 68, Batch 40, Pixel Loss: 0.022926
# Pre-train Epoch 69, Batch 0, Pixel Loss: 0.032211
# Pre-train Epoch 69, Batch 10, Pixel Loss: 0.038415
# Pre-train Epoch 69, Batch 20, Pixel Loss: 0.035048
# Pre-train Epoch 69, Batch 30, Pixel Loss: 0.032675
# Pre-train Epoch 69, Batch 40, Pixel Loss: 0.025806
# Pre-train Epoch 70, Batch 0, Pixel Loss: 0.027825
# Pre-train Epoch 70, Batch 10, Pixel Loss: 0.034647
# Pre-train Epoch 70, Batch 20, Pixel Loss: 0.026343
# Pre-train Epoch 70, Batch 30, Pixel Loss: 0.028524
# Pre-train Epoch 70, Batch 40, Pixel Loss: 0.034965
# Pre-train Epoch 71, Batch 0, Pixel Loss: 0.030819
# Pre-train Epoch 71, Batch 10, Pixel Loss: 0.027879
# Pre-train Epoch 71, Batch 20, Pixel Loss: 0.032081
# Pre-train Epoch 71, Batch 30, Pixel Loss: 0.029364
# Pre-train Epoch 71, Batch 40, Pixel Loss: 0.025341
# Pre-train Epoch 72, Batch 0, Pixel Loss: 0.038648
# Pre-train Epoch 72, Batch 10, Pixel Loss: 0.034328
# Pre-train Epoch 72, Batch 20, Pixel Loss: 0.024122
# Pre-train Epoch 72, Batch 30, Pixel Loss: 0.023374
# Pre-train Epoch 72, Batch 40, Pixel Loss: 0.027738
# Pre-train Epoch 73, Batch 0, Pixel Loss: 0.022284
# Pre-train Epoch 73, Batch 10, Pixel Loss: 0.029359
# Pre-train Epoch 73, Batch 20, Pixel Loss: 0.026266
# Pre-train Epoch 73, Batch 30, Pixel Loss: 0.028946
# Pre-train Epoch 73, Batch 40, Pixel Loss: 0.032862
# Pre-train Epoch 74, Batch 0, Pixel Loss: 0.029415
# Pre-train Epoch 74, Batch 10, Pixel Loss: 0.028561
# Pre-train Epoch 74, Batch 20, Pixel Loss: 0.028722
# Pre-train Epoch 74, Batch 30, Pixel Loss: 0.032669
# Pre-train Epoch 74, Batch 40, Pixel Loss: 0.036379
# Pre-train Epoch 75, Batch 0, Pixel Loss: 0.045611
# Pre-train Epoch 75, Batch 10, Pixel Loss: 0.031467
# Pre-train Epoch 75, Batch 20, Pixel Loss: 0.026774
# Pre-train Epoch 75, Batch 30, Pixel Loss: 0.035279
# Pre-train Epoch 75, Batch 40, Pixel Loss: 0.031536
# Pre-train Epoch 76, Batch 0, Pixel Loss: 0.027985
# Pre-train Epoch 76, Batch 10, Pixel Loss: 0.018892
# Pre-train Epoch 76, Batch 20, Pixel Loss: 0.022324
# Pre-train Epoch 76, Batch 30, Pixel Loss: 0.023734
# Pre-train Epoch 76, Batch 40, Pixel Loss: 0.025968
# Pre-train Epoch 77, Batch 0, Pixel Loss: 0.040085
# Pre-train Epoch 77, Batch 10, Pixel Loss: 0.029691
# Pre-train Epoch 77, Batch 20, Pixel Loss: 0.024501
# Pre-train Epoch 77, Batch 30, Pixel Loss: 0.020735
# Pre-train Epoch 77, Batch 40, Pixel Loss: 0.029468
# Pre-train Epoch 78, Batch 0, Pixel Loss: 0.033981
# Pre-train Epoch 78, Batch 10, Pixel Loss: 0.027736
# Pre-train Epoch 78, Batch 20, Pixel Loss: 0.045054
# Pre-train Epoch 78, Batch 30, Pixel Loss: 0.047415
# Pre-train Epoch 78, Batch 40, Pixel Loss: 0.028689
# Pre-train Epoch 79, Batch 0, Pixel Loss: 0.044494
# Pre-train Epoch 79, Batch 10, Pixel Loss: 0.030669
# Pre-train Epoch 79, Batch 20, Pixel Loss: 0.047613
# Pre-train Epoch 79, Batch 30, Pixel Loss: 0.032776
# Pre-train Epoch 79, Batch 40, Pixel Loss: 0.026223
# Pre-train Epoch 80, Batch 0, Pixel Loss: 0.032314
# Pre-train Epoch 80, Batch 10, Pixel Loss: 0.030496
# Pre-train Epoch 80, Batch 20, Pixel Loss: 0.029904
# Pre-train Epoch 80, Batch 30, Pixel Loss: 0.032580
# Pre-train Epoch 80, Batch 40, Pixel Loss: 0.046852
# Pre-train Epoch 81, Batch 0, Pixel Loss: 0.037191
# Pre-train Epoch 81, Batch 10, Pixel Loss: 0.029499
# Pre-train Epoch 81, Batch 20, Pixel Loss: 0.024451
# Pre-train Epoch 81, Batch 30, Pixel Loss: 0.031782
# Pre-train Epoch 81, Batch 40, Pixel Loss: 0.024626
# Pre-train Epoch 82, Batch 0, Pixel Loss: 0.023459
# Pre-train Epoch 82, Batch 10, Pixel Loss: 0.026719
# Pre-train Epoch 82, Batch 20, Pixel Loss: 0.019443
# Pre-train Epoch 82, Batch 30, Pixel Loss: 0.033825
# Pre-train Epoch 82, Batch 40, Pixel Loss: 0.025815
# Pre-train Epoch 83, Batch 0, Pixel Loss: 0.025015
# Pre-train Epoch 83, Batch 10, Pixel Loss: 0.030129
# Pre-train Epoch 83, Batch 20, Pixel Loss: 0.036728
# Pre-train Epoch 83, Batch 30, Pixel Loss: 0.020279
# Pre-train Epoch 83, Batch 40, Pixel Loss: 0.029177
# Pre-train Epoch 84, Batch 0, Pixel Loss: 0.020858
# Pre-train Epoch 84, Batch 10, Pixel Loss: 0.026828
# Pre-train Epoch 84, Batch 20, Pixel Loss: 0.018629
# Pre-train Epoch 84, Batch 30, Pixel Loss: 0.031986
# Pre-train Epoch 84, Batch 40, Pixel Loss: 0.035549
# Pre-train Epoch 85, Batch 0, Pixel Loss: 0.029625
# Pre-train Epoch 85, Batch 10, Pixel Loss: 0.028007
# Pre-train Epoch 85, Batch 20, Pixel Loss: 0.030333
# Pre-train Epoch 85, Batch 30, Pixel Loss: 0.031888
# Pre-train Epoch 85, Batch 40, Pixel Loss: 0.040420
# Pre-train Epoch 86, Batch 0, Pixel Loss: 0.017907
# Pre-train Epoch 86, Batch 10, Pixel Loss: 0.025812
# Pre-train Epoch 86, Batch 20, Pixel Loss: 0.023772
# Pre-train Epoch 86, Batch 30, Pixel Loss: 0.025817
# Pre-train Epoch 86, Batch 40, Pixel Loss: 0.038094
# Pre-train Epoch 87, Batch 0, Pixel Loss: 0.028018
# Pre-train Epoch 87, Batch 10, Pixel Loss: 0.028056
# Pre-train Epoch 87, Batch 20, Pixel Loss: 0.032326
# Pre-train Epoch 87, Batch 30, Pixel Loss: 0.026210
# Pre-train Epoch 87, Batch 40, Pixel Loss: 0.027526
# Pre-train Epoch 88, Batch 0, Pixel Loss: 0.025285
# Pre-train Epoch 88, Batch 10, Pixel Loss: 0.027333
# Pre-train Epoch 88, Batch 20, Pixel Loss: 0.038588
# Pre-train Epoch 88, Batch 30, Pixel Loss: 0.023547
# Pre-train Epoch 88, Batch 40, Pixel Loss: 0.027001
# Pre-train Epoch 89, Batch 0, Pixel Loss: 0.021573
# Pre-train Epoch 89, Batch 10, Pixel Loss: 0.029715
# Pre-train Epoch 89, Batch 20, Pixel Loss: 0.036624
# Pre-train Epoch 89, Batch 30, Pixel Loss: 0.028474
# Pre-train Epoch 89, Batch 40, Pixel Loss: 0.028170
# Pre-train Epoch 90, Batch 0, Pixel Loss: 0.027556
# Pre-train Epoch 90, Batch 10, Pixel Loss: 0.027122
# Pre-train Epoch 90, Batch 20, Pixel Loss: 0.033396
# Pre-train Epoch 90, Batch 30, Pixel Loss: 0.026806
# Pre-train Epoch 90, Batch 40, Pixel Loss: 0.027338
# Pre-train Epoch 91, Batch 0, Pixel Loss: 0.021706
# Pre-train Epoch 91, Batch 10, Pixel Loss: 0.026848
# Pre-train Epoch 91, Batch 20, Pixel Loss: 0.035100
# Pre-train Epoch 91, Batch 30, Pixel Loss: 0.021795
# Pre-train Epoch 91, Batch 40, Pixel Loss: 0.026474
# Pre-train Epoch 92, Batch 0, Pixel Loss: 0.026580
# Pre-train Epoch 92, Batch 10, Pixel Loss: 0.026366
# Pre-train Epoch 92, Batch 20, Pixel Loss: 0.025672
# Pre-train Epoch 92, Batch 30, Pixel Loss: 0.030025
# Pre-train Epoch 92, Batch 40, Pixel Loss: 0.037466
# Pre-train Epoch 93, Batch 0, Pixel Loss: 0.022966
# Pre-train Epoch 93, Batch 10, Pixel Loss: 0.032925
# Pre-train Epoch 93, Batch 20, Pixel Loss: 0.030634
# Pre-train Epoch 93, Batch 30, Pixel Loss: 0.027451
# Pre-train Epoch 93, Batch 40, Pixel Loss: 0.016894
# Pre-train Epoch 94, Batch 0, Pixel Loss: 0.037677
# Pre-train Epoch 94, Batch 10, Pixel Loss: 0.020813
# Pre-train Epoch 94, Batch 20, Pixel Loss: 0.035784
# Pre-train Epoch 94, Batch 30, Pixel Loss: 0.025507
# Pre-train Epoch 94, Batch 40, Pixel Loss: 0.027062
# Pre-train Epoch 95, Batch 0, Pixel Loss: 0.024948
# Pre-train Epoch 95, Batch 10, Pixel Loss: 0.029075
# Pre-train Epoch 95, Batch 20, Pixel Loss: 0.040837
# Pre-train Epoch 95, Batch 30, Pixel Loss: 0.020532
# Pre-train Epoch 95, Batch 40, Pixel Loss: 0.027607
# Pre-train Epoch 96, Batch 0, Pixel Loss: 0.028963
# Pre-train Epoch 96, Batch 10, Pixel Loss: 0.020517
# Pre-train Epoch 96, Batch 20, Pixel Loss: 0.032604
# Pre-train Epoch 96, Batch 30, Pixel Loss: 0.031524
# Pre-train Epoch 96, Batch 40, Pixel Loss: 0.030576
# Pre-train Epoch 97, Batch 0, Pixel Loss: 0.025788
# Pre-train Epoch 97, Batch 10, Pixel Loss: 0.035763
# Pre-train Epoch 97, Batch 20, Pixel Loss: 0.024983
# Pre-train Epoch 97, Batch 30, Pixel Loss: 0.034426
# Pre-train Epoch 97, Batch 40, Pixel Loss: 0.033115
# Pre-train Epoch 98, Batch 0, Pixel Loss: 0.026186
# Pre-train Epoch 98, Batch 10, Pixel Loss: 0.022340
# Pre-train Epoch 98, Batch 20, Pixel Loss: 0.035007
# Pre-train Epoch 98, Batch 30, Pixel Loss: 0.023989
# Pre-train Epoch 98, Batch 40, Pixel Loss: 0.027506
# Pre-train Epoch 99, Batch 0, Pixel Loss: 0.038052
# Pre-train Epoch 99, Batch 10, Pixel Loss: 0.030662
# Pre-train Epoch 99, Batch 20, Pixel Loss: 0.030358
# Pre-train Epoch 99, Batch 30, Pixel Loss: 0.026409
# Pre-train Epoch 99, Batch 40, Pixel Loss: 0.031874
# Epoch 0/100, Step 0, G Loss: 13.280485153198242, D Loss: 1.390804648399353
# Epoch 0/100, Step 10, G Loss: 9.983092308044434, D Loss: 1.595563530921936
# Epoch 0/100, Step 20, G Loss: 11.481685638427734, D Loss: 1.5447843074798584
# Epoch 0/100, Step 30, G Loss: 11.560194969177246, D Loss: 1.5069208145141602
# Epoch 0/100, Step 40, G Loss: 11.611080169677734, D Loss: 1.4280625581741333
# Epoch 1/100, Step 0, G Loss: 14.480942726135254, D Loss: 1.4043267965316772
# Epoch 1/100, Step 10, G Loss: 6.85944128036499, D Loss: 1.4012190103530884
# Epoch 1/100, Step 20, G Loss: 10.100982666015625, D Loss: 1.399796962738037
# Epoch 1/100, Step 30, G Loss: 7.351566791534424, D Loss: 1.3898179531097412
# Epoch 1/100, Step 40, G Loss: 8.938228607177734, D Loss: 1.3886988162994385
# Epoch 2/100, Step 0, G Loss: 10.888954162597656, D Loss: 1.3894028663635254
# Epoch 2/100, Step 10, G Loss: 8.438263893127441, D Loss: 1.3883652687072754
# Epoch 2/100, Step 20, G Loss: 5.723939418792725, D Loss: 1.3878040313720703
# Epoch 2/100, Step 30, G Loss: 7.624944686889648, D Loss: 1.3895964622497559
# Epoch 2/100, Step 40, G Loss: 6.031478404998779, D Loss: 1.3871337175369263
# Epoch 3/100, Step 0, G Loss: 10.52199935913086, D Loss: 1.3871488571166992
# Epoch 3/100, Step 10, G Loss: 7.626373291015625, D Loss: 1.387030005455017
# Epoch 3/100, Step 20, G Loss: 11.659334182739258, D Loss: 1.390380859375
# Epoch 3/100, Step 30, G Loss: 8.683320999145508, D Loss: 1.3876694440841675
# Epoch 3/100, Step 40, G Loss: 6.840213298797607, D Loss: 1.387640357017517
# Epoch 4/100, Step 0, G Loss: 7.052544593811035, D Loss: 1.3877532482147217
# Epoch 4/100, Step 10, G Loss: 9.74244499206543, D Loss: 1.387467622756958
# Epoch 4/100, Step 20, G Loss: 9.13155460357666, D Loss: 1.3869982957839966
# Epoch 4/100, Step 30, G Loss: 6.386390209197998, D Loss: 1.3869825601577759
# Epoch 4/100, Step 40, G Loss: 7.185323715209961, D Loss: 1.3868131637573242
# Epoch 5/100, Step 0, G Loss: 11.483386039733887, D Loss: 1.3866572380065918
# Epoch 5/100, Step 10, G Loss: 6.316910266876221, D Loss: 1.3865721225738525
# Epoch 5/100, Step 20, G Loss: 6.262701988220215, D Loss: 1.3869121074676514
# Epoch 5/100, Step 30, G Loss: 10.971592903137207, D Loss: 1.3871067762374878
# Epoch 5/100, Step 40, G Loss: 9.319741249084473, D Loss: 1.3869720697402954
# Epoch 6/100, Step 0, G Loss: 10.396639823913574, D Loss: 1.3868488073349
# Epoch 6/100, Step 10, G Loss: 4.836009979248047, D Loss: 1.3865392208099365
# Epoch 6/100, Step 20, G Loss: 7.774918079376221, D Loss: 1.3865776062011719
# Epoch 6/100, Step 30, G Loss: 5.516509532928467, D Loss: 1.3866469860076904
# Epoch 6/100, Step 40, G Loss: 7.386635780334473, D Loss: 1.3865383863449097
# Epoch 7/100, Step 0, G Loss: 13.716468811035156, D Loss: 1.386833906173706
# Epoch 7/100, Step 10, G Loss: 7.144169330596924, D Loss: 1.3867160081863403
# Epoch 7/100, Step 20, G Loss: 6.554431438446045, D Loss: 1.3864824771881104
# Epoch 7/100, Step 30, G Loss: 5.087952613830566, D Loss: 1.386502981185913
# Epoch 7/100, Step 40, G Loss: 6.339929580688477, D Loss: 1.3863879442214966
# Epoch 8/100, Step 0, G Loss: 7.303782939910889, D Loss: 1.386831283569336
# Epoch 8/100, Step 10, G Loss: 5.315704345703125, D Loss: 1.3864721059799194
# Epoch 8/100, Step 20, G Loss: 4.892927169799805, D Loss: 1.3865214586257935
# Epoch 8/100, Step 30, G Loss: 7.412826061248779, D Loss: 1.386581301689148
# Epoch 8/100, Step 40, G Loss: 10.031875610351562, D Loss: 1.386470079421997
# Epoch 9/100, Step 0, G Loss: 5.823365688323975, D Loss: 1.3864169120788574
# Epoch 9/100, Step 10, G Loss: 9.724908828735352, D Loss: 1.3867075443267822
# Epoch 9/100, Step 20, G Loss: 3.8009674549102783, D Loss: 1.386507511138916
# Epoch 9/100, Step 30, G Loss: 7.779205322265625, D Loss: 1.386711835861206
# Epoch 9/100, Step 40, G Loss: 9.79902172088623, D Loss: 1.3864610195159912
# Epoch 10/100, Step 0, G Loss: 9.20942497253418, D Loss: 1.3865420818328857
# Epoch 10/100, Step 10, G Loss: 8.23781967163086, D Loss: 1.3865628242492676
# Epoch 10/100, Step 20, G Loss: 4.1356658935546875, D Loss: 1.386625051498413
# Epoch 10/100, Step 30, G Loss: 4.771762847900391, D Loss: 1.386420488357544
# Epoch 10/100, Step 40, G Loss: 5.349123954772949, D Loss: 1.3864216804504395
# Epoch 11/100, Step 0, G Loss: 6.657647609710693, D Loss: 1.3865201473236084
# Epoch 11/100, Step 10, G Loss: 9.90484619140625, D Loss: 1.3864470720291138
# Epoch 11/100, Step 20, G Loss: 7.8100266456604, D Loss: 1.3866201639175415
# Epoch 11/100, Step 30, G Loss: 5.849133491516113, D Loss: 1.3863855600357056
# Epoch 11/100, Step 40, G Loss: 7.151062965393066, D Loss: 1.3864471912384033
# Epoch 12/100, Step 0, G Loss: 4.229416370391846, D Loss: 1.3864128589630127
# Epoch 12/100, Step 10, G Loss: 9.489537239074707, D Loss: 1.3865025043487549
# Epoch 12/100, Step 20, G Loss: 6.920774936676025, D Loss: 1.3867137432098389
# Epoch 12/100, Step 30, G Loss: 8.734476089477539, D Loss: 1.3865330219268799
# Epoch 12/100, Step 40, G Loss: 7.605224609375, D Loss: 1.3863768577575684
# Epoch 13/100, Step 0, G Loss: 9.576809883117676, D Loss: 1.3865426778793335
# Epoch 13/100, Step 10, G Loss: 12.41409683227539, D Loss: 1.3867743015289307
# Epoch 13/100, Step 20, G Loss: 9.197504997253418, D Loss: 1.3867595195770264
# Epoch 13/100, Step 30, G Loss: 5.898505687713623, D Loss: 1.386430263519287
# Epoch 13/100, Step 40, G Loss: 6.461828708648682, D Loss: 1.3864283561706543
# Epoch 14/100, Step 0, G Loss: 7.062598705291748, D Loss: 1.3864636421203613
# Epoch 14/100, Step 10, G Loss: 6.792433261871338, D Loss: 1.3864580392837524
# Epoch 14/100, Step 20, G Loss: 9.837268829345703, D Loss: 1.386469841003418
# Epoch 14/100, Step 30, G Loss: 6.181530475616455, D Loss: 1.3865463733673096
# Epoch 14/100, Step 40, G Loss: 9.00009536743164, D Loss: 1.3864843845367432
# Epoch 15/100, Step 0, G Loss: 8.613844871520996, D Loss: 1.386528730392456
# Epoch 15/100, Step 10, G Loss: 6.022617816925049, D Loss: 1.3867439031600952
# Epoch 15/100, Step 20, G Loss: 8.623106002807617, D Loss: 1.3865373134613037
# Epoch 15/100, Step 30, G Loss: 6.791163921356201, D Loss: 1.386420488357544
# Epoch 15/100, Step 40, G Loss: 6.040156364440918, D Loss: 1.3865389823913574
# Epoch 16/100, Step 0, G Loss: 4.4507975578308105, D Loss: 1.386385440826416
# Epoch 16/100, Step 10, G Loss: 7.312649250030518, D Loss: 1.3864367008209229
# Epoch 16/100, Step 20, G Loss: 11.851126670837402, D Loss: 1.3864868879318237
# Epoch 16/100, Step 30, G Loss: 9.091922760009766, D Loss: 1.3864413499832153
# Epoch 16/100, Step 40, G Loss: 8.624639511108398, D Loss: 1.3864179849624634
# Epoch 17/100, Step 0, G Loss: 7.194333076477051, D Loss: 1.386395812034607
# Epoch 17/100, Step 10, G Loss: 5.2545270919799805, D Loss: 1.386474847793579
# Epoch 17/100, Step 20, G Loss: 6.245703220367432, D Loss: 1.3864054679870605
# Epoch 17/100, Step 30, G Loss: 11.337058067321777, D Loss: 1.3863775730133057
# Epoch 17/100, Step 40, G Loss: 5.773369789123535, D Loss: 1.3864116668701172
# Epoch 18/100, Step 0, G Loss: 7.457672119140625, D Loss: 1.3864730596542358
# Epoch 18/100, Step 10, G Loss: 6.174158096313477, D Loss: 1.386458158493042
# Epoch 18/100, Step 20, G Loss: 5.817975044250488, D Loss: 1.386376142501831
# Epoch 18/100, Step 30, G Loss: 9.001957893371582, D Loss: 1.3864058256149292
# Epoch 18/100, Step 40, G Loss: 5.3348822593688965, D Loss: 1.3864474296569824
# Epoch 19/100, Step 0, G Loss: 7.939931392669678, D Loss: 1.3864161968231201
# Epoch 19/100, Step 10, G Loss: 7.088310718536377, D Loss: 1.3864129781723022
# Epoch 19/100, Step 20, G Loss: 7.187980651855469, D Loss: 1.3863813877105713
# Epoch 19/100, Step 30, G Loss: 5.496923446655273, D Loss: 1.3863475322723389
# Epoch 19/100, Step 40, G Loss: 7.174776077270508, D Loss: 1.3864126205444336
# Epoch 20/100, Step 0, G Loss: 10.447402954101562, D Loss: 1.386492133140564
# Epoch 20/100, Step 10, G Loss: 3.780311346054077, D Loss: 1.3863924741744995
# Epoch 20/100, Step 20, G Loss: 8.296608924865723, D Loss: 1.3863627910614014
# Epoch 20/100, Step 30, G Loss: 3.7661235332489014, D Loss: 1.3863732814788818
# Epoch 20/100, Step 40, G Loss: 8.031207084655762, D Loss: 1.3863885402679443
# Epoch 21/100, Step 0, G Loss: 8.50899600982666, D Loss: 1.3864786624908447
# Epoch 21/100, Step 10, G Loss: 6.1648454666137695, D Loss: 1.3863788843154907
# Epoch 21/100, Step 20, G Loss: 8.276700019836426, D Loss: 1.3864022493362427
# Epoch 21/100, Step 30, G Loss: 9.677501678466797, D Loss: 1.3863940238952637
# Epoch 21/100, Step 40, G Loss: 5.294254302978516, D Loss: 1.3863861560821533
# Epoch 22/100, Step 0, G Loss: 7.342837333679199, D Loss: 1.3863942623138428
# Epoch 22/100, Step 10, G Loss: 4.959030628204346, D Loss: 1.3863282203674316
# Epoch 22/100, Step 20, G Loss: 6.686768054962158, D Loss: 1.3863904476165771
# Epoch 22/100, Step 30, G Loss: 7.229548454284668, D Loss: 1.3864340782165527
# Epoch 22/100, Step 40, G Loss: 7.801523685455322, D Loss: 1.3864426612854004
# Epoch 23/100, Step 0, G Loss: 6.749076843261719, D Loss: 1.3864026069641113
# Epoch 23/100, Step 10, G Loss: 8.351502418518066, D Loss: 1.386389970779419
# Epoch 23/100, Step 20, G Loss: 6.966217517852783, D Loss: 1.3863667249679565
# Epoch 23/100, Step 30, G Loss: 9.652037620544434, D Loss: 1.386359453201294
# Epoch 23/100, Step 40, G Loss: 10.964197158813477, D Loss: 1.3864376544952393
# Epoch 24/100, Step 0, G Loss: 7.218429088592529, D Loss: 1.386420726776123
# Epoch 24/100, Step 10, G Loss: 5.5280442237854, D Loss: 1.3863811492919922
# Epoch 24/100, Step 20, G Loss: 8.380182266235352, D Loss: 1.386406421661377
# Epoch 24/100, Step 30, G Loss: 7.462377548217773, D Loss: 1.3864145278930664
# Epoch 24/100, Step 40, G Loss: 11.36093521118164, D Loss: 1.3864357471466064
# Epoch 25/100, Step 0, G Loss: 8.587291717529297, D Loss: 1.386409878730774
# Epoch 25/100, Step 10, G Loss: 4.7438435554504395, D Loss: 1.3863332271575928
# Epoch 25/100, Step 20, G Loss: 3.97208833694458, D Loss: 1.3863437175750732
# Epoch 25/100, Step 30, G Loss: 6.8620524406433105, D Loss: 1.3864104747772217
# Epoch 25/100, Step 40, G Loss: 8.939459800720215, D Loss: 1.3863389492034912
# Epoch 26/100, Step 0, G Loss: 7.7226481437683105, D Loss: 1.3863730430603027
# Epoch 26/100, Step 10, G Loss: 4.625598430633545, D Loss: 1.3863368034362793
# Epoch 26/100, Step 20, G Loss: 7.777678489685059, D Loss: 1.3863906860351562
# Epoch 26/100, Step 30, G Loss: 5.413828372955322, D Loss: 1.3863959312438965
# Epoch 26/100, Step 40, G Loss: 6.512095928192139, D Loss: 1.3863842487335205
# Epoch 27/100, Step 0, G Loss: 5.51446533203125, D Loss: 1.3863364458084106
# Epoch 27/100, Step 10, G Loss: 10.87096881866455, D Loss: 1.3863862752914429
# Epoch 27/100, Step 20, G Loss: 5.829751968383789, D Loss: 1.3863277435302734
# Epoch 27/100, Step 30, G Loss: 5.479950428009033, D Loss: 1.3863270282745361
# Epoch 27/100, Step 40, G Loss: 10.04472541809082, D Loss: 1.3863917589187622
# Epoch 28/100, Step 0, G Loss: 7.642605304718018, D Loss: 1.3863976001739502
# Epoch 28/100, Step 10, G Loss: 7.90370512008667, D Loss: 1.3863592147827148
# Epoch 28/100, Step 20, G Loss: 7.285099029541016, D Loss: 1.386366605758667
# Epoch 28/100, Step 30, G Loss: 8.111473083496094, D Loss: 1.3863248825073242
# Epoch 28/100, Step 40, G Loss: 7.135423183441162, D Loss: 1.3863775730133057
# Epoch 29/100, Step 0, G Loss: 6.66173791885376, D Loss: 1.386338233947754
# Epoch 29/100, Step 10, G Loss: 5.183460235595703, D Loss: 1.3863551616668701
# Epoch 29/100, Step 20, G Loss: 8.585687637329102, D Loss: 1.3863608837127686
# Epoch 29/100, Step 30, G Loss: 7.703758716583252, D Loss: 1.3863873481750488
# Epoch 29/100, Step 40, G Loss: 5.8236775398254395, D Loss: 1.3863314390182495
# Epoch 30/100, Step 0, G Loss: 5.4361114501953125, D Loss: 1.386335849761963
# Epoch 30/100, Step 10, G Loss: 10.257865905761719, D Loss: 1.3863227367401123
# Epoch 30/100, Step 20, G Loss: 6.731657028198242, D Loss: 1.3863264322280884
# Epoch 30/100, Step 30, G Loss: 7.937154293060303, D Loss: 1.3863681554794312
# Epoch 30/100, Step 40, G Loss: 6.2858710289001465, D Loss: 1.3863816261291504
# Epoch 31/100, Step 0, G Loss: 7.8966383934021, D Loss: 1.3863513469696045
# Epoch 31/100, Step 10, G Loss: 8.158048629760742, D Loss: 1.386362910270691
# Epoch 31/100, Step 20, G Loss: 4.832805156707764, D Loss: 1.3863409757614136
# Epoch 31/100, Step 30, G Loss: 8.722801208496094, D Loss: 1.3863694667816162
# Epoch 31/100, Step 40, G Loss: 8.536737442016602, D Loss: 1.3863792419433594
# Epoch 32/100, Step 0, G Loss: 6.437160015106201, D Loss: 1.3863389492034912
# Epoch 32/100, Step 10, G Loss: 5.709716320037842, D Loss: 1.386335849761963
# Epoch 32/100, Step 20, G Loss: 5.3419575691223145, D Loss: 1.3863093852996826
# Epoch 32/100, Step 30, G Loss: 6.327445983886719, D Loss: 1.3863348960876465
# Epoch 32/100, Step 40, G Loss: 12.127281188964844, D Loss: 1.3864188194274902
# Epoch 33/100, Step 0, G Loss: 4.548269271850586, D Loss: 1.386325716972351
# Epoch 33/100, Step 10, G Loss: 7.462267875671387, D Loss: 1.3863717317581177
# Epoch 33/100, Step 20, G Loss: 5.921286106109619, D Loss: 1.3863376379013062
# Epoch 33/100, Step 30, G Loss: 13.983832359313965, D Loss: 1.3863396644592285
# Epoch 33/100, Step 40, G Loss: 8.114420890808105, D Loss: 1.3864068984985352
# Epoch 34/100, Step 0, G Loss: 6.21840238571167, D Loss: 1.3863270282745361
# Epoch 34/100, Step 10, G Loss: 3.158881425857544, D Loss: 1.386314868927002
# Epoch 34/100, Step 20, G Loss: 6.871823787689209, D Loss: 1.3863285779953003
# Epoch 34/100, Step 30, G Loss: 7.1038970947265625, D Loss: 1.3863450288772583
# Epoch 34/100, Step 40, G Loss: 10.118074417114258, D Loss: 1.3863484859466553
# Epoch 35/100, Step 0, G Loss: 8.476643562316895, D Loss: 1.3863344192504883
# Epoch 35/100, Step 10, G Loss: 6.871707916259766, D Loss: 1.3863461017608643
# Epoch 35/100, Step 20, G Loss: 6.850917339324951, D Loss: 1.3863344192504883
# Epoch 35/100, Step 30, G Loss: 8.298667907714844, D Loss: 1.3863636255264282
# Epoch 35/100, Step 40, G Loss: 6.255472660064697, D Loss: 1.386362075805664
# Epoch 36/100, Step 0, G Loss: 8.680379867553711, D Loss: 1.3863388299942017
# Epoch 36/100, Step 10, G Loss: 6.29136848449707, D Loss: 1.3863344192504883
# Epoch 36/100, Step 20, G Loss: 3.6232571601867676, D Loss: 1.3863089084625244
# Epoch 36/100, Step 30, G Loss: 6.898818492889404, D Loss: 1.3863224983215332
# Epoch 36/100, Step 40, G Loss: 10.970151901245117, D Loss: 1.386351466178894
# Epoch 37/100, Step 0, G Loss: 8.231846809387207, D Loss: 1.3863544464111328
# Epoch 37/100, Step 10, G Loss: 7.499971866607666, D Loss: 1.3863568305969238
# Epoch 37/100, Step 20, G Loss: 6.876198768615723, D Loss: 1.3863444328308105
# Epoch 37/100, Step 30, G Loss: 10.290586471557617, D Loss: 1.3863272666931152
# Epoch 37/100, Step 40, G Loss: 8.703587532043457, D Loss: 1.3863441944122314
# Epoch 38/100, Step 0, G Loss: 6.025770664215088, D Loss: 1.386340618133545
# Epoch 38/100, Step 10, G Loss: 7.380914211273193, D Loss: 1.3863370418548584
# Epoch 38/100, Step 20, G Loss: 6.638193130493164, D Loss: 1.3863227367401123
# Epoch 38/100, Step 30, G Loss: 9.138319969177246, D Loss: 1.3863335847854614
# Epoch 38/100, Step 40, G Loss: 8.08701229095459, D Loss: 1.386335015296936
# Epoch 39/100, Step 0, G Loss: 8.680984497070312, D Loss: 1.386332631111145
# Epoch 39/100, Step 10, G Loss: 6.637894630432129, D Loss: 1.3863134384155273
# Epoch 39/100, Step 20, G Loss: 7.249202251434326, D Loss: 1.3863729238510132
# Epoch 39/100, Step 30, G Loss: 8.301844596862793, D Loss: 1.3863563537597656
# Epoch 39/100, Step 40, G Loss: 5.5299153327941895, D Loss: 1.3863205909729004
# Epoch 40/100, Step 0, G Loss: 8.797313690185547, D Loss: 1.386338472366333
# Epoch 40/100, Step 10, G Loss: 6.691436290740967, D Loss: 1.38631010055542
# Epoch 40/100, Step 20, G Loss: 5.472409248352051, D Loss: 1.3863166570663452
# Epoch 40/100, Step 30, G Loss: 7.081376552581787, D Loss: 1.3863246440887451
# Epoch 40/100, Step 40, G Loss: 6.545514106750488, D Loss: 1.3863158226013184
# Epoch 41/100, Step 0, G Loss: 5.841215133666992, D Loss: 1.3863258361816406
# Epoch 41/100, Step 10, G Loss: 10.646903991699219, D Loss: 1.3863277435302734
# Epoch 41/100, Step 20, G Loss: 5.671698093414307, D Loss: 1.3863184452056885
# Epoch 41/100, Step 30, G Loss: 7.887702465057373, D Loss: 1.3863420486450195
# Epoch 41/100, Step 40, G Loss: 2.3205251693725586, D Loss: 1.3863188028335571
# Epoch 42/100, Step 0, G Loss: 6.681884288787842, D Loss: 1.3863129615783691
# Epoch 42/100, Step 10, G Loss: 14.764852523803711, D Loss: 1.386370062828064
# Epoch 42/100, Step 20, G Loss: 5.8248701095581055, D Loss: 1.3863255977630615
# Epoch 42/100, Step 30, G Loss: 5.76348352432251, D Loss: 1.3863251209259033
# Epoch 42/100, Step 40, G Loss: 9.666175842285156, D Loss: 1.3863146305084229
# Epoch 43/100, Step 0, G Loss: 7.265508651733398, D Loss: 1.3863275051116943
# Epoch 43/100, Step 10, G Loss: 5.183638095855713, D Loss: 1.3863203525543213
# Epoch 43/100, Step 20, G Loss: 8.163225173950195, D Loss: 1.3863046169281006
# Epoch 43/100, Step 30, G Loss: 11.499119758605957, D Loss: 1.386319637298584
# Epoch 43/100, Step 40, G Loss: 7.918254852294922, D Loss: 1.386326551437378
# Epoch 44/100, Step 0, G Loss: 7.767293453216553, D Loss: 1.386310338973999
# Epoch 44/100, Step 10, G Loss: 8.30893325805664, D Loss: 1.3863165378570557
# Epoch 44/100, Step 20, G Loss: 8.516165733337402, D Loss: 1.386335849761963
# Epoch 44/100, Step 30, G Loss: 7.582457542419434, D Loss: 1.3863084316253662
# Epoch 44/100, Step 40, G Loss: 8.327095985412598, D Loss: 1.3863191604614258
# Epoch 45/100, Step 0, G Loss: 5.6291913986206055, D Loss: 1.3863178491592407
# Epoch 45/100, Step 10, G Loss: 8.711325645446777, D Loss: 1.3863308429718018
# Epoch 45/100, Step 20, G Loss: 5.1753339767456055, D Loss: 1.3863155841827393
# Epoch 45/100, Step 30, G Loss: 7.545699596405029, D Loss: 1.3863036632537842
# Epoch 45/100, Step 40, G Loss: 7.1802778244018555, D Loss: 1.3863197565078735
# Epoch 46/100, Step 0, G Loss: 10.349649429321289, D Loss: 1.3863239288330078
# Epoch 46/100, Step 10, G Loss: 6.652259349822998, D Loss: 1.3863306045532227
# Epoch 46/100, Step 20, G Loss: 8.517801284790039, D Loss: 1.386336326599121
# Epoch 46/100, Step 30, G Loss: 10.512073516845703, D Loss: 1.3863334655761719
# Epoch 46/100, Step 40, G Loss: 10.593866348266602, D Loss: 1.3863245248794556
# Epoch 47/100, Step 0, G Loss: 10.027450561523438, D Loss: 1.3863468170166016
# Epoch 47/100, Step 10, G Loss: 8.040581703186035, D Loss: 1.3863177299499512
# Epoch 47/100, Step 20, G Loss: 6.603241443634033, D Loss: 1.3863157033920288
# Epoch 47/100, Step 30, G Loss: 8.93104076385498, D Loss: 1.386329174041748
# Epoch 47/100, Step 40, G Loss: 6.263459205627441, D Loss: 1.3863093852996826
# Epoch 48/100, Step 0, G Loss: 4.889040470123291, D Loss: 1.386301040649414
# Epoch 48/100, Step 10, G Loss: 8.088831901550293, D Loss: 1.3863136768341064
# Epoch 48/100, Step 20, G Loss: 7.824330806732178, D Loss: 1.386308193206787
# Epoch 48/100, Step 30, G Loss: 3.8509299755096436, D Loss: 1.3863017559051514
# Epoch 48/100, Step 40, G Loss: 7.562641143798828, D Loss: 1.3863251209259033
# Epoch 49/100, Step 0, G Loss: 6.880162239074707, D Loss: 1.3863275051116943
# Epoch 49/100, Step 10, G Loss: 5.162422180175781, D Loss: 1.386312484741211
# Epoch 49/100, Step 20, G Loss: 9.14421272277832, D Loss: 1.3863154649734497
# Epoch 49/100, Step 30, G Loss: 9.217000007629395, D Loss: 1.386321783065796
# Epoch 49/100, Step 40, G Loss: 9.483428001403809, D Loss: 1.3863284587860107
# Epoch 50/100, Step 0, G Loss: 5.909275531768799, D Loss: 1.386317253112793
# Epoch 50/100, Step 10, G Loss: 4.380873203277588, D Loss: 1.386303186416626
# Epoch 50/100, Step 20, G Loss: 6.796207904815674, D Loss: 1.3863108158111572
# Epoch 50/100, Step 30, G Loss: 7.9247660636901855, D Loss: 1.3863201141357422
# Epoch 50/100, Step 40, G Loss: 7.721076011657715, D Loss: 1.3863070011138916
# Epoch 51/100, Step 0, G Loss: 8.63667106628418, D Loss: 1.386314868927002
# Epoch 51/100, Step 10, G Loss: 6.512182235717773, D Loss: 1.3863193988800049
# Epoch 51/100, Step 20, G Loss: 8.782309532165527, D Loss: 1.3863327503204346
# Epoch 51/100, Step 30, G Loss: 7.0580525398254395, D Loss: 1.3863166570663452
# Epoch 51/100, Step 40, G Loss: 7.168490409851074, D Loss: 1.3863136768341064
# Epoch 52/100, Step 0, G Loss: 6.4867987632751465, D Loss: 1.3863146305084229
# Epoch 52/100, Step 10, G Loss: 8.834989547729492, D Loss: 1.3863112926483154
# Epoch 52/100, Step 20, G Loss: 7.584768772125244, D Loss: 1.3863083124160767
# Epoch 52/100, Step 30, G Loss: 8.270965576171875, D Loss: 1.3863227367401123
# Epoch 52/100, Step 40, G Loss: 6.410547733306885, D Loss: 1.3863009214401245
# Epoch 53/100, Step 0, G Loss: 6.402895450592041, D Loss: 1.3863098621368408
# Epoch 53/100, Step 10, G Loss: 6.526070594787598, D Loss: 1.3863089084625244
# Epoch 53/100, Step 20, G Loss: 5.4054155349731445, D Loss: 1.386309266090393
# Epoch 53/100, Step 30, G Loss: 7.807877063751221, D Loss: 1.3863327503204346
# Epoch 53/100, Step 40, G Loss: 5.4645280838012695, D Loss: 1.3863089084625244
# Epoch 54/100, Step 0, G Loss: 4.064074516296387, D Loss: 1.3863162994384766
# Epoch 54/100, Step 10, G Loss: 6.333991527557373, D Loss: 1.3863160610198975
# Epoch 54/100, Step 20, G Loss: 8.866915702819824, D Loss: 1.386317253112793
# Epoch 54/100, Step 30, G Loss: 6.8107500076293945, D Loss: 1.386311411857605
# Epoch 54/100, Step 40, G Loss: 7.965034008026123, D Loss: 1.3863062858581543
# Epoch 55/100, Step 0, G Loss: 14.05331039428711, D Loss: 1.3863232135772705
# Epoch 55/100, Step 10, G Loss: 7.945878028869629, D Loss: 1.3863170146942139
# Epoch 55/100, Step 20, G Loss: 5.593838691711426, D Loss: 1.3863155841827393
# Epoch 55/100, Step 30, G Loss: 8.783618927001953, D Loss: 1.386305332183838
# Epoch 55/100, Step 40, G Loss: 5.682019233703613, D Loss: 1.3863145112991333
# Epoch 56/100, Step 0, G Loss: 9.308658599853516, D Loss: 1.386315941810608
# Epoch 56/100, Step 10, G Loss: 7.604152679443359, D Loss: 1.3863341808319092
# Epoch 56/100, Step 20, G Loss: 3.8759615421295166, D Loss: 1.3863190412521362
# Epoch 56/100, Step 30, G Loss: 10.246001243591309, D Loss: 1.3863167762756348
# Epoch 56/100, Step 40, G Loss: 5.344429969787598, D Loss: 1.38631272315979
# Epoch 57/100, Step 0, G Loss: 6.852275371551514, D Loss: 1.3863104581832886
# Epoch 57/100, Step 10, G Loss: 7.645504474639893, D Loss: 1.386306643486023
# Epoch 57/100, Step 20, G Loss: 7.588192462921143, D Loss: 1.3863047361373901
# Epoch 57/100, Step 30, G Loss: 6.579443454742432, D Loss: 1.3863065242767334
# Epoch 57/100, Step 40, G Loss: 7.974813938140869, D Loss: 1.3863139152526855
# Epoch 58/100, Step 0, G Loss: 4.73499059677124, D Loss: 1.3863182067871094
# Epoch 58/100, Step 10, G Loss: 7.597413539886475, D Loss: 1.386303424835205
# Epoch 58/100, Step 20, G Loss: 6.392287731170654, D Loss: 1.386308193206787
# Epoch 58/100, Step 30, G Loss: 9.559223175048828, D Loss: 1.3863152265548706
# Epoch 58/100, Step 40, G Loss: 5.645064353942871, D Loss: 1.3863061666488647
# Epoch 59/100, Step 0, G Loss: 9.754413604736328, D Loss: 1.3863105773925781
# Epoch 59/100, Step 10, G Loss: 5.916182994842529, D Loss: 1.3863141536712646
# Epoch 59/100, Step 20, G Loss: 7.597475051879883, D Loss: 1.3863201141357422
# Epoch 59/100, Step 30, G Loss: 6.144290924072266, D Loss: 1.3863074779510498
# Epoch 59/100, Step 40, G Loss: 8.651498794555664, D Loss: 1.3863041400909424
# Epoch 60/100, Step 0, G Loss: 4.499430179595947, D Loss: 1.386305332183838
# Epoch 60/100, Step 10, G Loss: 7.5324015617370605, D Loss: 1.386315107345581
# Epoch 60/100, Step 20, G Loss: 4.568505764007568, D Loss: 1.3863191604614258
# Epoch 60/100, Step 30, G Loss: 5.915913105010986, D Loss: 1.386305570602417
# Epoch 60/100, Step 40, G Loss: 10.050531387329102, D Loss: 1.386316180229187
# Epoch 61/100, Step 0, G Loss: 8.47317123413086, D Loss: 1.3863158226013184
# Epoch 61/100, Step 10, G Loss: 11.066818237304688, D Loss: 1.3863084316253662
# Epoch 61/100, Step 20, G Loss: 8.063111305236816, D Loss: 1.386308193206787
# Epoch 61/100, Step 30, G Loss: 5.674743175506592, D Loss: 1.386307954788208
# Epoch 61/100, Step 40, G Loss: 7.822290420532227, D Loss: 1.3863086700439453
# Epoch 62/100, Step 0, G Loss: 6.383187294006348, D Loss: 1.3862991333007812
# Epoch 62/100, Step 10, G Loss: 6.084867477416992, D Loss: 1.3863060474395752
# Epoch 62/100, Step 20, G Loss: 5.856398105621338, D Loss: 1.3863158226013184
# Epoch 62/100, Step 30, G Loss: 7.561943531036377, D Loss: 1.3863096237182617
# Epoch 62/100, Step 40, G Loss: 5.714542865753174, D Loss: 1.386308193206787
# Epoch 63/100, Step 0, G Loss: 8.152812004089355, D Loss: 1.3863085508346558
# Epoch 63/100, Step 10, G Loss: 6.526161193847656, D Loss: 1.386308193206787
# Epoch 63/100, Step 20, G Loss: 8.588366508483887, D Loss: 1.3863143920898438
# Epoch 63/100, Step 30, G Loss: 7.668115139007568, D Loss: 1.3863143920898438
# Epoch 63/100, Step 40, G Loss: 7.97578763961792, D Loss: 1.3863091468811035
# Epoch 64/100, Step 0, G Loss: 8.188813209533691, D Loss: 1.3863084316253662
# Epoch 64/100, Step 10, G Loss: 10.44945240020752, D Loss: 1.3863073587417603
# Epoch 64/100, Step 20, G Loss: 8.564863204956055, D Loss: 1.386299729347229
# Epoch 64/100, Step 30, G Loss: 8.036236763000488, D Loss: 1.3863157033920288
# Epoch 64/100, Step 40, G Loss: 4.9277544021606445, D Loss: 1.3863046169281006
# Epoch 65/100, Step 0, G Loss: 13.071584701538086, D Loss: 1.3863228559494019
# Epoch 65/100, Step 10, G Loss: 7.868076324462891, D Loss: 1.3863213062286377
# Epoch 65/100, Step 20, G Loss: 6.408202171325684, D Loss: 1.386307954788208
# Epoch 65/100, Step 30, G Loss: 9.720283508300781, D Loss: 1.3863095045089722
# Epoch 65/100, Step 40, G Loss: 9.839431762695312, D Loss: 1.3863131999969482
# Epoch 66/100, Step 0, G Loss: 8.261972427368164, D Loss: 1.3863201141357422
# Epoch 66/100, Step 10, G Loss: 9.848403930664062, D Loss: 1.386317491531372
# Epoch 66/100, Step 20, G Loss: 8.66137981414795, D Loss: 1.3863118886947632
# Epoch 66/100, Step 30, G Loss: 9.937443733215332, D Loss: 1.386307716369629
# Epoch 66/100, Step 40, G Loss: 5.30759334564209, D Loss: 1.38630211353302
# Epoch 67/100, Step 0, G Loss: 6.728924751281738, D Loss: 1.386307954788208
# Epoch 67/100, Step 10, G Loss: 7.760807037353516, D Loss: 1.3863123655319214
# Epoch 67/100, Step 20, G Loss: 5.607449531555176, D Loss: 1.3863019943237305
# Epoch 67/100, Step 30, G Loss: 9.681596755981445, D Loss: 1.3863184452056885
# Epoch 67/100, Step 40, G Loss: 10.586044311523438, D Loss: 1.3863065242767334
# Epoch 68/100, Step 0, G Loss: 4.813262462615967, D Loss: 1.3863122463226318
# Epoch 68/100, Step 10, G Loss: 8.559691429138184, D Loss: 1.3862993717193604
# Epoch 68/100, Step 20, G Loss: 7.3377509117126465, D Loss: 1.3863022327423096
# Epoch 68/100, Step 30, G Loss: 9.629451751708984, D Loss: 1.386310338973999
# Epoch 68/100, Step 40, G Loss: 10.180134773254395, D Loss: 1.3863050937652588
# Epoch 69/100, Step 0, G Loss: 9.920896530151367, D Loss: 1.3863017559051514
# Epoch 69/100, Step 10, G Loss: 9.263113021850586, D Loss: 1.3863120079040527
# Epoch 69/100, Step 20, G Loss: 8.879484176635742, D Loss: 1.3863083124160767
# Epoch 69/100, Step 30, G Loss: 6.868707656860352, D Loss: 1.386313557624817
# Epoch 69/100, Step 40, G Loss: 8.857870101928711, D Loss: 1.386308193206787
# Epoch 70/100, Step 0, G Loss: 4.685168266296387, D Loss: 1.386301875114441
# Epoch 70/100, Step 10, G Loss: 6.609482288360596, D Loss: 1.3863070011138916
# Epoch 70/100, Step 20, G Loss: 9.500585556030273, D Loss: 1.3863098621368408
# Epoch 70/100, Step 30, G Loss: 7.821516513824463, D Loss: 1.3863005638122559
# Epoch 70/100, Step 40, G Loss: 8.389779090881348, D Loss: 1.3863023519515991
# Epoch 71/100, Step 0, G Loss: 5.722387313842773, D Loss: 1.3863005638122559
# Epoch 71/100, Step 10, G Loss: 9.396339416503906, D Loss: 1.3863177299499512
# Epoch 71/100, Step 20, G Loss: 6.69817590713501, D Loss: 1.3863033056259155
# Epoch 71/100, Step 30, G Loss: 6.255045413970947, D Loss: 1.386303186416626
# Epoch 71/100, Step 40, G Loss: 10.959858894348145, D Loss: 1.3863089084625244
# Epoch 72/100, Step 0, G Loss: 6.330746173858643, D Loss: 1.3863017559051514
# Epoch 72/100, Step 10, G Loss: 8.397141456604004, D Loss: 1.38629949092865
# Epoch 72/100, Step 20, G Loss: 5.471559047698975, D Loss: 1.3862998485565186
# Epoch 72/100, Step 30, G Loss: 10.08927059173584, D Loss: 1.3863027095794678
# Epoch 72/100, Step 40, G Loss: 11.197983741760254, D Loss: 1.3863052129745483
# Epoch 73/100, Step 0, G Loss: 7.0497727394104, D Loss: 1.3863017559051514
# Epoch 73/100, Step 10, G Loss: 7.79026460647583, D Loss: 1.386304497718811
# Epoch 73/100, Step 20, G Loss: 4.8230156898498535, D Loss: 1.3862974643707275
# Epoch 73/100, Step 30, G Loss: 5.2433085441589355, D Loss: 1.3863000869750977
# Epoch 73/100, Step 40, G Loss: 6.109967231750488, D Loss: 1.3863017559051514
# Epoch 74/100, Step 0, G Loss: 8.488860130310059, D Loss: 1.386305809020996
# Epoch 74/100, Step 10, G Loss: 7.981683731079102, D Loss: 1.386316180229187
# Epoch 74/100, Step 20, G Loss: 6.519647121429443, D Loss: 1.386305332183838
# Epoch 74/100, Step 30, G Loss: 7.08890962600708, D Loss: 1.3863049745559692
# Epoch 74/100, Step 40, G Loss: 7.786107540130615, D Loss: 1.3863062858581543
# Epoch 75/100, Step 0, G Loss: 5.481766223907471, D Loss: 1.3863028287887573
# Epoch 75/100, Step 10, G Loss: 11.36852741241455, D Loss: 1.386309266090393
# Epoch 75/100, Step 20, G Loss: 5.541774272918701, D Loss: 1.3863000869750977
# Epoch 75/100, Step 30, G Loss: 5.933791160583496, D Loss: 1.386303186416626
# Epoch 75/100, Step 40, G Loss: 4.970083236694336, D Loss: 1.3862998485565186
# Epoch 76/100, Step 0, G Loss: 8.5101957321167, D Loss: 1.386298418045044
# Epoch 76/100, Step 10, G Loss: 4.995254993438721, D Loss: 1.386299967765808
# Epoch 76/100, Step 20, G Loss: 6.247960567474365, D Loss: 1.3863073587417603
# Epoch 76/100, Step 30, G Loss: 7.097248554229736, D Loss: 1.3863011598587036
# Epoch 76/100, Step 40, G Loss: 8.799888610839844, D Loss: 1.3863039016723633
# Epoch 77/100, Step 0, G Loss: 6.985397815704346, D Loss: 1.3862998485565186
# Epoch 77/100, Step 10, G Loss: 8.553074836730957, D Loss: 1.386303186416626
# Epoch 77/100, Step 20, G Loss: 4.963979244232178, D Loss: 1.3862993717193604
# Epoch 77/100, Step 30, G Loss: 8.559744834899902, D Loss: 1.3863104581832886
# Epoch 77/100, Step 40, G Loss: 5.748688697814941, D Loss: 1.3863015174865723
# Epoch 78/100, Step 0, G Loss: 5.560145378112793, D Loss: 1.3863005638122559
# Epoch 78/100, Step 10, G Loss: 6.124761581420898, D Loss: 1.3863091468811035
# Epoch 78/100, Step 20, G Loss: 3.0205724239349365, D Loss: 1.3862971067428589
# Epoch 78/100, Step 30, G Loss: 8.250675201416016, D Loss: 1.3862993717193604
# Epoch 78/100, Step 40, G Loss: 6.2245988845825195, D Loss: 1.3863078355789185
# Epoch 79/100, Step 0, G Loss: 6.321221828460693, D Loss: 1.3863065242767334
# Epoch 79/100, Step 10, G Loss: 6.106839179992676, D Loss: 1.386298656463623
# Epoch 79/100, Step 20, G Loss: 6.0141425132751465, D Loss: 1.3862969875335693
# Epoch 79/100, Step 30, G Loss: 5.999990940093994, D Loss: 1.3863000869750977
# Epoch 79/100, Step 40, G Loss: 5.674517631530762, D Loss: 1.3863015174865723
# Epoch 80/100, Step 0, G Loss: 6.727007865905762, D Loss: 1.3863064050674438
# Epoch 80/100, Step 10, G Loss: 5.971073627471924, D Loss: 1.386314034461975
# Epoch 80/100, Step 20, G Loss: 6.001875400543213, D Loss: 1.386301040649414
# Epoch 80/100, Step 30, G Loss: 7.867193222045898, D Loss: 1.3863004446029663
# Epoch 80/100, Step 40, G Loss: 5.474679470062256, D Loss: 1.3863028287887573
# Epoch 81/100, Step 0, G Loss: 8.20947551727295, D Loss: 1.3862991333007812
# Epoch 81/100, Step 10, G Loss: 7.297279357910156, D Loss: 1.3863011598587036
# Epoch 81/100, Step 20, G Loss: 5.470363140106201, D Loss: 1.3862993717193604
# Epoch 81/100, Step 30, G Loss: 6.4333648681640625, D Loss: 1.3863015174865723
# Epoch 81/100, Step 40, G Loss: 8.103971481323242, D Loss: 1.3863029479980469
# Epoch 82/100, Step 0, G Loss: 11.056303977966309, D Loss: 1.3863049745559692
# Epoch 82/100, Step 10, G Loss: 9.506086349487305, D Loss: 1.3863049745559692
# Epoch 82/100, Step 20, G Loss: 7.954897880554199, D Loss: 1.3863003253936768
# Epoch 82/100, Step 30, G Loss: 12.76550006866455, D Loss: 1.3863039016723633
# Epoch 82/100, Step 40, G Loss: 8.935317039489746, D Loss: 1.3862991333007812
# Epoch 83/100, Step 0, G Loss: 5.301838397979736, D Loss: 1.3863048553466797
# Epoch 83/100, Step 10, G Loss: 4.125267505645752, D Loss: 1.3862998485565186
# Epoch 83/100, Step 20, G Loss: 6.105222225189209, D Loss: 1.3862987756729126
# Epoch 83/100, Step 30, G Loss: 6.8587870597839355, D Loss: 1.3863023519515991
# Epoch 83/100, Step 40, G Loss: 7.4005866050720215, D Loss: 1.3862974643707275
# Epoch 84/100, Step 0, G Loss: 5.5205888748168945, D Loss: 1.386301040649414
# Epoch 84/100, Step 10, G Loss: 8.252472877502441, D Loss: 1.3863015174865723
# Epoch 84/100, Step 20, G Loss: 9.468242645263672, D Loss: 1.3863030672073364
# Epoch 84/100, Step 30, G Loss: 7.651562213897705, D Loss: 1.386301040649414
# Epoch 84/100, Step 40, G Loss: 10.028084754943848, D Loss: 1.386308193206787
# Epoch 85/100, Step 0, G Loss: 5.037967681884766, D Loss: 1.3863039016723633
# Epoch 85/100, Step 10, G Loss: 7.5250043869018555, D Loss: 1.3862979412078857
# Epoch 85/100, Step 20, G Loss: 8.608953475952148, D Loss: 1.3863048553466797
# Epoch 85/100, Step 30, G Loss: 5.6936869621276855, D Loss: 1.3862990140914917
# Epoch 85/100, Step 40, G Loss: 7.609254837036133, D Loss: 1.386301875114441
# Epoch 86/100, Step 0, G Loss: 5.803854942321777, D Loss: 1.3862985372543335
# Epoch 86/100, Step 10, G Loss: 7.81558084487915, D Loss: 1.3862988948822021
# Epoch 86/100, Step 20, G Loss: 8.76974105834961, D Loss: 1.3862990140914917
# Epoch 86/100, Step 30, G Loss: 8.335193634033203, D Loss: 1.3862993717193604
# Epoch 86/100, Step 40, G Loss: 7.471056938171387, D Loss: 1.3863046169281006
# Epoch 87/100, Step 0, G Loss: 8.195952415466309, D Loss: 1.3863015174865723
# Epoch 87/100, Step 10, G Loss: 5.247182369232178, D Loss: 1.3862985372543335
# Epoch 87/100, Step 20, G Loss: 11.454116821289062, D Loss: 1.3863039016723633
# Epoch 87/100, Step 30, G Loss: 5.572554111480713, D Loss: 1.3863036632537842
# Epoch 87/100, Step 40, G Loss: 7.624561309814453, D Loss: 1.386297345161438
# Epoch 88/100, Step 0, G Loss: 6.020073413848877, D Loss: 1.386299729347229
# Epoch 88/100, Step 10, G Loss: 6.803229331970215, D Loss: 1.3863061666488647
# Epoch 88/100, Step 20, G Loss: 6.184828758239746, D Loss: 1.3862988948822021
# Epoch 88/100, Step 30, G Loss: 8.653568267822266, D Loss: 1.3863085508346558
# Epoch 88/100, Step 40, G Loss: 9.007658004760742, D Loss: 1.386300802230835
# Epoch 89/100, Step 0, G Loss: 7.3289713859558105, D Loss: 1.38629949092865
# Epoch 89/100, Step 10, G Loss: 8.331192016601562, D Loss: 1.3863030672073364
# Epoch 89/100, Step 20, G Loss: 6.50980806350708, D Loss: 1.386298656463623
# Epoch 89/100, Step 30, G Loss: 7.753890514373779, D Loss: 1.3863049745559692
# Epoch 89/100, Step 40, G Loss: 9.136590957641602, D Loss: 1.386298656463623
# Epoch 90/100, Step 0, G Loss: 5.531516075134277, D Loss: 1.3863039016723633
# Epoch 90/100, Step 10, G Loss: 6.47725772857666, D Loss: 1.3863015174865723
# Epoch 90/100, Step 20, G Loss: 6.19720458984375, D Loss: 1.3863083124160767
# Epoch 90/100, Step 30, G Loss: 7.005493640899658, D Loss: 1.3862991333007812
# Epoch 90/100, Step 40, G Loss: 8.569424629211426, D Loss: 1.386301040649414
# Epoch 91/100, Step 0, G Loss: 7.982738971710205, D Loss: 1.386298656463623
# Epoch 91/100, Step 10, G Loss: 7.417388916015625, D Loss: 1.3862991333007812
# Epoch 91/100, Step 20, G Loss: 7.2773919105529785, D Loss: 1.3862998485565186
# Epoch 91/100, Step 30, G Loss: 9.561637878417969, D Loss: 1.3862988948822021
# Epoch 91/100, Step 40, G Loss: 8.544711112976074, D Loss: 1.3863016366958618
# Epoch 92/100, Step 0, G Loss: 8.075322151184082, D Loss: 1.3862996101379395
# Epoch 92/100, Step 10, G Loss: 5.647233963012695, D Loss: 1.3863072395324707
# Epoch 92/100, Step 20, G Loss: 9.057707786560059, D Loss: 1.3863046169281006
# Epoch 92/100, Step 30, G Loss: 9.107030868530273, D Loss: 1.3862996101379395
# Epoch 92/100, Step 40, G Loss: 4.819224834442139, D Loss: 1.386298656463623
# Epoch 93/100, Step 0, G Loss: 9.384718894958496, D Loss: 1.3863019943237305
# Epoch 93/100, Step 10, G Loss: 3.9518234729766846, D Loss: 1.3862968683242798
# Epoch 93/100, Step 20, G Loss: 6.417445182800293, D Loss: 1.3862981796264648
# Epoch 93/100, Step 30, G Loss: 7.1732048988342285, D Loss: 1.386298418045044
# Epoch 93/100, Step 40, G Loss: 7.834239482879639, D Loss: 1.3863030672073364
# Epoch 94/100, Step 0, G Loss: 5.138431549072266, D Loss: 1.3863002061843872
# Epoch 94/100, Step 10, G Loss: 8.665756225585938, D Loss: 1.3863015174865723
# Epoch 94/100, Step 20, G Loss: 7.151596546173096, D Loss: 1.3862988948822021
# Epoch 94/100, Step 30, G Loss: 7.108423233032227, D Loss: 1.386298418045044
# Epoch 94/100, Step 40, G Loss: 6.869839191436768, D Loss: 1.3863011598587036
# Epoch 95/100, Step 0, G Loss: 7.852353572845459, D Loss: 1.386300802230835
# Epoch 95/100, Step 10, G Loss: 4.794443607330322, D Loss: 1.3862991333007812
# Epoch 95/100, Step 20, G Loss: 9.501691818237305, D Loss: 1.3863036632537842
# Epoch 95/100, Step 30, G Loss: 6.144827365875244, D Loss: 1.3863012790679932
# Epoch 95/100, Step 40, G Loss: 6.6965012550354, D Loss: 1.3862990140914917
# Epoch 96/100, Step 0, G Loss: 8.13677978515625, D Loss: 1.3863039016723633
# Epoch 96/100, Step 10, G Loss: 7.563508987426758, D Loss: 1.3862981796264648
# Epoch 96/100, Step 20, G Loss: 7.038342475891113, D Loss: 1.3862981796264648
# Epoch 96/100, Step 30, G Loss: 5.571901798248291, D Loss: 1.3863048553466797
# Epoch 96/100, Step 40, G Loss: 8.881418228149414, D Loss: 1.3863009214401245
# Epoch 97/100, Step 0, G Loss: 8.140007019042969, D Loss: 1.386297345161438
# Epoch 97/100, Step 10, G Loss: 7.843996524810791, D Loss: 1.3862972259521484
# Epoch 97/100, Step 20, G Loss: 7.200777053833008, D Loss: 1.3862998485565186
# Epoch 97/100, Step 30, G Loss: 5.699069499969482, D Loss: 1.3862982988357544
# Epoch 97/100, Step 40, G Loss: 5.908492565155029, D Loss: 1.3862981796264648
# Epoch 98/100, Step 0, G Loss: 6.4913177490234375, D Loss: 1.3862988948822021
# Epoch 98/100, Step 10, G Loss: 5.039750099182129, D Loss: 1.3862965106964111
# Epoch 98/100, Step 20, G Loss: 11.247627258300781, D Loss: 1.3863003253936768
# Epoch 98/100, Step 30, G Loss: 4.682165145874023, D Loss: 1.386297345161438
# Epoch 98/100, Step 40, G Loss: 4.744815349578857, D Loss: 1.3862981796264648
# Epoch 99/100, Step 0, G Loss: 7.421153545379639, D Loss: 1.3863015174865723
# Epoch 99/100, Step 10, G Loss: 9.74284553527832, D Loss: 1.3863035440444946
# Epoch 99/100, Step 20, G Loss: 4.569493770599365, D Loss: 1.3862981796264648
# Epoch 99/100, Step 30, G Loss: 5.506698131561279, D Loss: 1.3862969875335693
# Epoch 99/100, Step 40, G Loss: 6.880002498626709, D Loss: 1.386300802230835

# %%
torch.save(generator.state_dict(), 'RRDB_ESRGAN.pth')

# %%
def inference(generator, hr_dir, lr_dir):
    val_files = os.listdir(hr_dir)

    hr_images = []
    hr_y_s = []
    sr_y_s = []
    cr_images = []
    cb_images = []
    generator.eval()
    with torch.no_grad():
        for file in val_files:
            hr_name = os.path.join(hr_dir, file)
            lr_name = os.path.join(lr_dir, file)
            hr_img = Image.open(hr_name).convert('YCbCr')
            hr_images.append(hr_img)
            hr_y,_,_ = hr_img.split()
            hr_y = ToTensor()(hr_y)
            hr_y_s.append(hr_y)
            lr_img = Image.open(lr_name).convert('YCbCr')
            lr_y,lr_cb,lr_cr = lr_img.split()
            lr_y = ToTensor()(lr_y).to(device)
            cr_images.append(lr_cr)
            cb_images.append(lr_cb)
            
            sr_y = generator(lr_y.unsqueeze(0))
            sr_y_s.append(sr_y.squeeze(0).cpu())
    return hr_images, hr_y_s, sr_y_s, cr_images, cb_images

def calculate_psnr(sr, hr):
    mse = F.mse_loss(sr, hr)
    return 10 * torch.log10(1.0 / mse)

def calculate_ssim(sr, hr):
    sr_np = sr.permute(1, 2, 0).numpy()
    hr_np = hr.permute(1, 2, 0).numpy()
    
    sr_np = np.clip(sr_np, 0, 1)
    hr_np = np.clip(hr_np, 0, 1)
    
    return ssim(sr_np, hr_np, data_range=1.0, channel_axis=2, multichannel=True)

def test(generator, hr_dir, lr_dir):
    hr_images, hr_y_s, sr_y_s, cr_images, cb_images = inference(generator, hr_dir, lr_dir)
    psnr_errors = []
    SSIM_errors = []
    for i in range(len(hr_y_s)):
        psnr_errors.append(calculate_psnr(sr_y_s[i], hr_y_s[i]).item())
        SSIM_errors.append(calculate_ssim(sr_y_s[i], hr_y_s[i]).item())
    
    return np.mean(psnr_errors), np.mean(SSIM_errors)

# %%
generator = Generator().to(device)
generator.load_state_dict(torch.load("RRDB_ESRGAN.pth"))
generator.eval()
# Out:
# /tmp/ipykernel_1318432/959341785.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   generator.load_state_dict(torch.load("RRDB_ESRGAN.pth"))
# Generator(
#   (intial_block): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (1): PReLU(num_parameters=1)
#   )
#   (res_block): Sequential(
#     (0): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (1): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (2): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (3): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (4): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (5): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (6): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (7): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (8): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (9): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (10): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (11): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (12): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (13): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (14): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (15): ResidualResidualDenseBlock(
#       (rdb1): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb2): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#       (rdb3): ResidualDenseBlock(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv3): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv4): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv5): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (lRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#   )
#   (post_res): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (upsample_block): Sequential(
#     (0): UpSample(
#       (upsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PixelShuffle(upscale_factor=2)
#         (2): PReLU(num_parameters=1)
#       )
#     )
#     (1): UpSample(
#       (upsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PixelShuffle(upscale_factor=2)
#         (2): PReLU(num_parameters=1)
#       )
#     )
#   )
#   (final): Conv2d(64, 1, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
# )

# %%
hr_dir = "DIV2K_valid_HR"
lr_dir = "DIV2K_valid_LR_bicubic_X4"
psnr, SSIM = test(generator, hr_dir, lr_dir)
print(f'for the DIV2K validation set the PSNR is {psnr} and SSIM is {SSIM}')
# Out:
# for the DIV2K validation set the PSNR is 26.643590755462647 and SSIM is 0.7623343706130982

# %%
hr_dir = "Set5/HR"
lr_dir = "Set5/LR"
psnr, SSIM = test(generator, hr_dir, lr_dir)
print(f'for the Set5 dataset the PSNR is {psnr} and SSIM is {SSIM}')
# Out:
# for the Set5 dataset the PSNR is 27.4662166595459 and SSIM is 0.8284645915031433

# %%
hr_dir = "Set14/HR"
lr_dir = "Set14/LR"
psnr, SSIM = test(generator, hr_dir, lr_dir)
print(f'for the Set14 dataset the PSNR is {psnr} and SSIM is {SSIM}')
# Out:
# for the Set14 dataset the PSNR is 24.837641988481796 and SSIM is 0.7080316841602325

# %%
val_files = os.listdir("Set5/HR")

generator.eval()
with torch.no_grad():
        hr_name = os.path.join(hr_dir, val_files[2])
        lr_name = os.path.join(lr_dir, val_files[2])
        hr_img = Image.open(hr_name).convert('YCbCr')
        hr_y,_,_ = hr_img.split()
        lr_img = Image.open(lr_name).convert('YCbCr')
        lr_y,lr_cb,lr_cr = lr_img.split()
        lr_y = ToTensor()(lr_y).to(device)
        
        sr_y = generator(lr_y.unsqueeze(0))
        sr_y = sr_y.squeeze(0).cpu()

sr_y_np = sr_y.squeeze().cpu().clamp(0, 1).numpy() * 255.0
sr_y_np = sr_y_np.astype(np.uint8)
sr_y_img = Image.fromarray(sr_y_np, mode='L')

new_size = sr_y_img.size
cb_up = lr_cb.resize(new_size, Image.BICUBIC)
cr_up = lr_cr.resize(new_size, Image.BICUBIC)

img_ycbcr = Image.merge("YCbCr", [sr_y_img, cb_up, cr_up])
img_rgb = img_ycbcr.convert("RGB")
hr_img_rgb = hr_img.convert("RGB")

# %%
fig, ax = plt.subplots(1,2, figsize=(20, 10))

ax[0].imshow(hr_img_rgb)
ax[0].axis("off")
ax[0].set_title("HR image")

ax[1].imshow(img_rgb)
ax[1].axis("off")
ax[1].set_title("SR image by ESRGAN")

plt.show()
fig.savefig("compare_images_ESRGAN.png")

# %%
img_rgb.save("SR_image_ESRGAN.png")
